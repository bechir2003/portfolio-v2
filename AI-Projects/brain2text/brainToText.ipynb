# %% [markdown]
# # Neural Data Preprocessing Workflow
#
# This notebook demonstrates a step-by-step workflow for preprocessing neural data stored in `.mat` files. The goal is to extract meaningful features and labels for training machine learning models. Below are the key steps:
#
# 1. **Load Data**: Import all `.mat` files from the training folder and store them in a structured format.
# 2. **Explore Data**: Inspect the contents of a sample `.mat` file to understand the structure and types of data available.
# 3. **Feature Extraction**: Extract neural features (e.g., `spikePow` and `tx1`) and corresponding labels (e.g., `sentenceText`) from all trials.
# 4. **Normalization**: Apply block-wise z-score normalization to ensure consistent scaling across trials.
# 5. **Dataset Preparation**: Combine features and labels into a format suitable for training machine learning models.
#
# Let’s begin by importing the necessary libraries and loading the data.

# %%
import os
import scipy.io
import numpy as np
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense, Embedding, TimeDistributed

# %% [markdown]
# 🧠 Step 1 (Updated): Load All .mat Files from a Folder
# Let’s write code to:
#
# List all .mat files in your training folder
#
# Load each file
#
# Store them in a dictionary (or list) where each key is the filename

# %%
# Replace with the actual path to your training folder
data_folder = 'dataset/train/'

# List all .mat files in the folder
mat_files = [f for f in os.listdir(data_folder) if f.endswith('.mat')]
print(f"Found {len(mat_files)} .mat files")

# Load all .mat files into a dictionary
data_list = {}

for file in mat_files:
    file_path = os.path.join(data_folder, file)
    data = scipy.io.loadmat(file_path)
    data_list[file] = data  # store using filename as key

# Show keys of one sample file
sample_file = mat_files[0]
print(f"Keys in one sample ({sample_file}):")
print(data_list[sample_file].keys())
# Out:
# Found 24 .mat files
# Keys in one sample (t12.2022.04.28.mat):
# dict_keys(['__header__', '__version__', '__globals__', 'sentenceText', 'tx1', 'tx2', 'tx3', 'tx4', 'spikePow', 'blockIdx'])

# %% [markdown]
# 🧠 Step 2: Explore One Sample Trial
# We want to:
#
# Inspect the contents of one .mat file
#
# Understand the shape and type of the neural features and text

# %%
# Choose one sample file from the loaded data
sample = list(data_list.values())[0]  # first trial

# Print available variables in this trial
print("Keys in sample trial:", sample.keys())

# Let's see what spikePow and sentenceText look like
spike_pow = sample['spikePow']
tx1 = sample['tx1']
sentence_text = sample['sentenceText']

print("Type of spikePow:", type(spike_pow))
print("Shape of spikePow:", np.array(spike_pow).shape)

print("Type of tx1:", type(tx1))
print("Shape of tx1:", np.array(tx1).shape)

print("Sentence text:")
print(sentence_text)
# Out:
# Keys in sample trial: dict_keys(['__header__', '__version__', '__globals__', 'sentenceText', 'tx1', 'tx2', 'tx3', 'tx4', 'spikePow', 'blockIdx'])
# Type of spikePow: <class 'numpy.ndarray'>
# Shape of spikePow: (1, 280)
# Type of tx1: <class 'numpy.ndarray'>
# Shape of tx1: (1, 280)
# Sentence text:
# ['Nuclear rockets can destroy airfields with ease.                                      '
#  'The best way to learn is to solve extra problems.                                     '
#  'The spray will be used in first division matches next season.                         '
#  "Our experiment's positive outcome was unexpected.                                     "
#  "Alimony harms a divorced man's wealth.                                                "
#  'She uses both names interchangeably.                                                  '
#  'The misquote was retracted with an apology.                                           '
#  'Critics fear the erosion of consumer protections and environmental standards.         '
#  'Her lips, moist and parted, spoke his name.                                           '
#  'How do they turn out later?                                                           '
#  'The eastern coast is a place for pure pleasure and excitement.                        '
#  'Please make your decision wisely to visit the Beach.                                  '
#  'She encouraged her children to make their own Halloween costumes.                     '
#  'Cleaned cloth must be protected against the redeposition of dispersed soil.           '
#  'Both figures would go higher in later years.                                          '
#  'She always jokes about too much garlic in his food.                                   '
#  'If people were more generous, there would be no need for welfare.                     '
#  'The dimensions of these waves dwarf all our usual standards of measurement.           '
#  'The knifelike pain in his groin nearly brought him down again.                        '
#  'Selecting bunks by economic comparison is usually an individual problem.              '
#  'Have a test-run on the family first, to be sure timing and seasoning are right.       '
#  'A good attitude is unbeatable.                                                        '
#  'Make lid for sugar bowl the same as jar lids, omitting design disk.                   '
#  "It's healthier to cook without sugar.                                                 "
#  'Ironically enough, in this instance such personal virtues were a luxury.              '
#  'Every cab needs repainting often.                                                     '
#  'Coconut cream pie makes a nice dessert.                                               '
#  'George seldom watches daytime movies.                                                 '
#  'Wooded stream valleys in the folds of earth would be saved.                           '
#  'The nearest synagogue may not be within walking distance.                             '
#  'Some measures on student debt relief have already been taken.                         '
#  'Morphophonemic rules may be thought of as joining certain points in the system.       '
#  'His talk turns to what he calls the mess, or sometimes this buzzing confusion.        '
#  'The structures housing the apartments are of masonry and frame construction.          '
#  "I ate every oyster on Nora's plate.                                                   "
#  'Usually, they occur through Facebook.                                                 '
#  'Hastily the boy switched on a ceiling light.                                          '
#  'I do struggle with visuals but will do a higher dose sometime soon.                   '
#  'Call an ambulance for medical assistance.                                             '
#  'Usually it snaps back into place by morning.                                          '
#  "He doesn't want her to look frowningly at him, or speak to him angrily.               "
#  'Almonds and pistachio nuts are not so high in oil but are rich in protein.            '
#  'The cigarettes in the clay ashtray overflowed onto the oak table.                     '
#  'The measures require parliamentary approval before they can come into force.          '
#  'We produce peanut oil, but to a much greater extent we eat the entire seed.           '
#  'His election, on the other hand, would unquestionably strengthen the regulars.        '
#  'Do atypical farmers grow oats?                                                        '
#  'Further, it has its work cut out stopping anarchy where it is now garrisoned.         '
#  'My desires are simple: give me one informative paragraph on the subject.              '
#  "Our boy didn't chicken out, no sir.                                                   "
#  'The moisture in my eyes is from eyedrops, not from tears.                             '
#  'The staff deserves a lot of credit working down here under real obstacles.            '
#  'One needs to protect the skin from exposure to the sun.                               '
#  'Suburban housewives often suffer from the gab habit.                                  '
#  'Grandmother outgrew her upbringing in petticoats.                                     '
#  "John's brother repainted the garage door.                                             "
#  'An octillion atoms -- now let us see where this power comes from.                     '
#  'They own a big house in the remote countryside.                                       '
#  'He banked his treasure in the hearts of his friends.                                  '
#  'Nothing has been done yet to take advantage of the enabling legislation.              '
#  'Our enemy is also threatening to devour us.                                           '
#  'No manufacturer has taken the initiative in pointing out the costs involved.          '
#  'And according to the new revisions, they might very well change.                      '
#  'Fill that canteen with fresh spring water.                                            '
#  "He doesn't want her to look frowningly at him, or speak to him angrily.               "
#  'Angora cats are furrier than Siamese.                                                 '
#  "Employee layoffs coincided with the company's reorganization.                         "
#  'Microorganisms are often responsible for the rapid spoilage of foods.                 '
#  'Is a relaxed home atmosphere enough to help her outgrow these traits?                 '
#  'He may have a point in urging that decadent themes be given fewer prizes.             '
#  'The emblem depicts the Acropolis all aglow.                                           '
#  'The local drugstore was charged with illegally dispensing tranquilizers.              '
#  'That noise problem grows more annoying each day.                                      '
#  'His shoulder felt as if it were broken.                                               '
#  'Do they make class-biased decisions?                                                  '
#  'Cliff was soothed by the luxurious massage.                                           '
#  'Eating spinach nightly increases strength miraculously.                               '
#  'His failure to open the store by eight cost him his job.                              '
#  'The emperor had a mean temper.                                                        '
#  'This big, flexible voice with uncommon range has been superbly disciplined.           '
#  'Birthday parties have cupcakes and ice cream.                                         '
#  'We congratulate the entire membership on its record of good legislation.              '
#  "You people don't have adjustable vision.                                              "
#  'He looked lazy, spoiled, a little querulous.                                          '
#  'The toddler found a clamshell near the camp site.                                     '
#  'Westchester is a county in New York.                                                  '
#  'How ancient is this subway escalator?                                                 '
#  "They're doin' it now.                                                                 "
#  'If you destroy confidence in banks, you do something to the economy, he said.         '
#  'Hispanic costumes are quite colorful.                                                 '
#  'An official deadline cannot be postponed.                                             '
#  "But the ships are very slow now, and we don't get so many sailors any more.           "
#  'They were shown how to advance against an enemy outpost atop a cleared ridge.         '
#  'Eat your raisins outdoors on the porch steps.                                         '
#  'Historical existence is a created good.                                               '
#  'Puree some fruit before preparing the skewers.                                        '
#  'That diagram makes sense only after much study.                                       '
#  'Lots of foreign movies have subtitles.                                                '
#  'Trim away excess clay; reinforce seam with a coil of clay.                            '
#  'Allow each child to have an ice pop.                                                  '
#  'For me it has more of both elements than the majority of its competitors.             '
#  'He was above all a friend seeker, almost pathetic in his eagerness to be liked.       '
#  'Thus there is a clearer division of authority, administrative and legislative.        '
#  'He may have a point in urging that decadent themes be given fewer prizes.             '
#  "That's an illusion.                                                                   "
#  'Iguanas and alligators are tropical reptiles.                                         '
#  'A voice spoke near-at-hand.                                                           '
#  'A screwdriver is made from vodka and orange juice.                                    '
#  'A lone star shone in the early evening sky.                                           '
#  'She looked crestfallen, as if he had somehow disappointed the whole human race.       '
#  'This was easy for us.                                                                 '
#  "Daphne's Swedish needlepoint scarf matched her skirt.                                 "
#  'He who does not love abides in death.                                                 '
#  'Further, it has its work cut out stopping anarchy where it is now garrisoned.         '
#  "It's fun to roast marshmallows on a gas burner.                                       "
#  'The measure now moves to the Senate floor for a vote.                                 '
#  'Palm oil protects the surfaces of steel sheets before they are plated with tin.       '
#  'Seamstresses attach zippers with a thimble, needle, and thread.                       '
#  'In your garden it usually breaks down within a few days.                              '
#  'We have touched on many topics, from backpacking all the way through to luxury travel.'
#  'Try to recall the events in chronological order.                                      '
#  'Bob papered over the living room murals.                                              '
#  'What happens after looters find treasure?                                             '
#  'Would such an act of refusal be useful?                                               '
#  'The thick elm forest was nearly overwhelmed by Dutch Elm Disease.                     '
#  'Are you looking for employment?                                                       '
#  "Cliff's display was misplaced on the screen.                                          "
#  "Norwegian sweaters are made of lamb's wool.                                           "
#  'This news was published on the old version of the website.                            '
#  'In fact our whole defensive unit did a good job.                                      '
#  'A leather handbag would be a suitable gift.                                           '
#  'For a moment, boy and mount hung in midair.                                           '
#  'Her classical performance gained critical acclaim.                                    '
#  'Mosquitoes exist in warm, humid climates.                                             '
#  'Thick glue oozed out of the tube.                                                     '
#  'Draw each graph on a new axis.                                                        '
#  'The new birth is miraculous and mysterious.                                           '
#  'Drop five forms in the box before you go out.                                         '
#  'But how little love we give him!                                                      '
#  'They should live in modest circumstances, avoiding all conspicuous consumption.       '
#  'Reading in poor light gives you eyestrain.                                            '
#  'Next best to destroying an army is to deprive it of its freedom of action.            '
#  'Or certain words or rituals that child and adult go through may do the trick.         '
#  'Which church do the Smiths worship in?                                                '
#  "The barracuda recoiled from the serpent's poisonous fangs.                            "
#  "You're so preoccupied that you've let your faith grow dim.                            "
#  'Remember to allow identical twins to enter freely.                                    '
#  'A connoisseur will enjoy this shellfish dish.                                         '
#  'If they are not ellipsoids, the conclusions will be a reasonable approximation.       '
#  'Wider discretionary choices for customers.                                            '
#  'Steph could barely handle the psychological trauma.                                   '
#  'How oily do you like your salad dressing?                                             '
#  "Severe myopia contributed to Ron's inferiority complex.                               "
#  'Destroy every file related to my audits.                                              '
#  'Valley Lodge yearly celebrates the first calf born.                                   '
#  'Steve collects rare and novel coins.                                                  '
#  'Scholastic aptitude is judged by standardized tests.                                  '
#  'He enlisted a staff of loyal experts and of many zealous volunteers.                  '
#  'Castor oil, made from castorbeans, has gone out of style as a medicine.               '
#  "Take charge of choosing her bride's maids' gowns.                                     "
#  'Movies never have enough villains.                                                    '
#  'Keep your seats, boys, I just want to put some finishing touches on this thing.       '
#  'The fifth jar contains big, juicy peaches.                                            '
#  'Look at the things we do to escape our fears and to forget our worries.               '
#  'Shipbuilding is a most fascinating process.                                           '
#  'The triumphant warrior exhibited naive heroism.                                       '
#  'Maybe he will help to turn our fair city into a ghost town.                           '
#  'It is those measures which are now being prepared.                                    '
#  'Stories like that of her and her son are not unusual.                                 '
#  'In fact our whole defensive unit did a good job.                                      '
#  'Curiosity and mediocrity seldom coexist.                                              '
#  'Do line barbecue fire bowl with heavy foil to reflect heat.                           '
#  'They remained lifelong friends and companions.                                        '
#  'Pizzerias are convenient for a quick lunch.                                           '
#  'My ideal morning begins with hot coffee.                                              '
#  'His body processes only slowed down enough for him to dispel fatigue poisons.         '
#  'Growing well-kept gardens is very time consuming.                                     '
#  'Laugh, dance, and sing if fortune smiles upon you.                                    '
#  'Objects made of pewter are beautiful.                                                 '
#  'What is this large thing by the ironing board?                                        '
#  'You will usually be guided.                                                           '
#  'This can be easily visualized with the following simple graph.                        '
#  'Should giraffes be kept in small zoos?                                                '
#  'Any groups with bookings affected by the partial closure have been notified, he said. '
#  'Jokes, cartoons and cynics to the contrary, mothers-in-law make good friends.         '
#  'We welcome many new students each year.                                               '
#  'Flying standby can be practical if you want to save money.                            '
#  'He picked up nine pairs of socks for each brother.                                    '
#  'We experience distress and frustration obtaining our degrees.                         '
#  'My beloved ward, my perennial gadfly, said the whining voice.                         '
#  'As a precaution, the outlaws bought gunpowder for their stronghold.                   '
#  'Put on his old brown corduroy coat and it was already soaked.                         '
#  'A muscular abdomen is good for your back.                                             '
#  'The small boy put the worm on the hook.                                               '
#  'Regular attendance is seldom required.                                                '
#  'Beg that guard for one gallon of gas.                                                 '
#  'There may be some problems with news display in specific browser versions.            '
#  'She is thinner than I am.                                                             '
#  'He stole a dime from a beggar.                                                        '
#  'Do they allow atheists in church?                                                     '
#  'Please sing just the club theme.                                                      '
#  'Addition and subtraction are learned skills.                                          '
#  'The morning dew on the spider web glistened in the sun.                               '
#  'We also spent a great deal of effort on making a demo version.                        '
#  "Challenge each general's intelligence.                                                "
#  'A sleepy voice answered.                                                              '
#  'Envision a life you love.                                                             '
#  'Only the most accomplished artists obtain popularity.                                 '
#  'We are open every Monday evening.                                                     '
#  'Artificial intelligence is for real.                                                  '
#  'Brush fires are common in the dry underbrush of Nevada.                               '
#  'Residential associations struggle to insulate themselves against intrusions.          '
#  "Are your grades higher or lower than Nancy's?                                         "
#  'The mango and the papaya are in a bowl.                                               '
#  'Rob sat by the pond and sketched the stray geese.                                     '
#  "However, a boy's lively eyes might rove.                                              "
#  "He believed that brave boys didn't cry.                                               "
#  'We have also seen the power of faith at work among us.                                '
#  'Our entire economy will have a terrific uplift.                                       '
#  "Yeah, seems so, don't it, the boy laughed, hugging her close.                         "
#  'The giant redwoods shimmered in the glistening sun.                                   '
#  'Count the number of teaspoons of soysauce that you add.                               '
#  'The legislature met to judge the state of public education.                           '
#  'That pickpocket was caught red-handed.                                                '
#  'The viewpoint overlooked the ocean.                                                   '
#  'Measured performance characteristics for this experimental tube will be listed.       '
#  'Her right hand aches whenever the barometric pressure changes.                        '
#  'Neglect means spiritual paralysis or death.                                           '
#  'A chosen few will become Generals.                                                    '
#  'Will Robin wear a yellow lily?                                                        '
#  'Once you finish greasing your chain, be sure to wash thoroughly.                      '
#  'These caged versions can be traded and sold.                                          '
#  'But people need to be part of the equation.                                           '
#  'We could barely see the fjords through the snow flurries.                             '
#  'The public is now armed with sophistication and numerous competing media.             '
#  'Policymakers usually take turns giving their view of the economy.                     '
#  'A skin mole is usually round or oval in shape and appears as a spot on the skin.      '
#  "Students' choices of ideal educational goals are not arbitrary or whimsical.          "
#  'In developing film, many toxic chemicals are used.                                    '
#  'We got drenched from the uninterrupted rain.                                          '
#  'She came back the other day to reassure me.                                           '
#  'The dark, murky lagoon wound around for miles.                                        '
#  'He may toss coins; he may take slips of paper from a grab bag.                        '
#  'As coauthors, we presented our new book to the haughty audience.                      '
#  'Also make sure thermometer does not touch the revolving spit or hit the coals.        '
#  "You're so preoccupied that you've let your faith grow dim.                            "
#  'Psychologically the reception should be the climax, following the sermon.             '
#  'Our enemy is also threatening to devour us.                                           '
#  'We would lose our export markets and deny ourselves the imports we need.              '
#  "The cat's meow always hurts my ears.                                                  "
#  "The singer's finger had a splinter.                                                   "
#  'His sudden departure shocked the cast.                                                '
#  'How permanent are their records?                                                      '
#  'The fifth one wore a Prestige uniform.                                                '
#  'The news agency hired a great journalist.                                             '
#  'Coffee is grown on steep, jungle-like slopes in temperate zones.                      '
#  'Technical writers can abbreviate in bibliographies.                                   '
#  'Now a distinguished old man called on nine divinities to come and join us.            '
#  'A toothpaste tube should be squeezed from the bottom.                                 '
#  'Bright sunshine shimmers on the ocean.                                                '
#  "I've written so many versions of this conversation.                                   "
#  'Most of us brush our teeth by hand.                                                   '
#  'Project development was proceeding too slowly.                                        '
#  'There was typhoid and malaria.                                                        '
#  'The kid has no manners, boys.                                                         '
#  "The cowboy's humorous name for a cow givin' milk was a milk pitcher.                  "
#  'Almost all colleges are now coeducational.                                            '
#  'Many wealthy tycoons splurged and bought both a yacht and a schooner.                 '
#  'Critical equipment needs proper maintenance.                                          '
#  'The narrow fringe of sadness that ran around it only emphasized the pleasure.         '
#  'If necessary to replace both halves on grill, sear cuts and allot extra time.         '
#  'Her face turned pink with pleasure and a smothered cough.                             '
#  'The desire and ability to read are important aspects of our cultural life.            '
#  'Theirs is a sacrificial life by earthly standards.                                    '
#  'Does Creole cooking use curry?                                                        '
#  'Her wardrobe consists of only skirts and blouses.                                     '
#  'The old shop adage still holds: a good mechanic is usually a bad boss.                '
#  'Please take this dirty table cloth to the cleaners for me.                            '
#  'A good morrow to you, my boy.                                                         '
#  'The irate actor stomped away idiotically.                                             ']

# %% [markdown]
# 🧠 Step 3: Extract Features & Labels from All Trials
#
# Loop through all .mat files
#
# For each file, extract:
#
# The neural data from spikePow and tx1 (and optionally combine them)
#
# The sentence text (as the label)
#
# Store them into a list so we can build a training dataset

# %%
# Area 6v only: use first 128 channels
area6v_indices = np.arange(0, 128)

# Hold all features and labels
X = []
y = []

# Loop over all .mat training files
for filename in os.listdir(data_folder):
    if filename.endswith('.mat'):
        file_path = os.path.join(data_folder, filename)
        mat = scipy.io.loadmat(file_path)

        spikePow = mat['spikePow'].squeeze()  # S-length array of matrices
        tx1 = mat['tx1'].squeeze()
        blockIdx = mat['blockIdx'].squeeze()
        sentenceText = mat['sentenceText']

        num_trials = len(spikePow)

        for i in range(num_trials):
            # Combine tx1 and spikePow: each is (T x F), we use first 128 channels (Area 6v)
            spike_trial = spikePow[i][:, area6v_indices]
            tx1_trial = tx1[i][:, area6v_indices]
            
            # Concatenate along feature axis: (T x 128) → (T x 256)
            trial_features = np.concatenate([spike_trial, tx1_trial], axis=1)

            # Normalize using block-wise z-score
            block_id = blockIdx[i]
            block_mask = (blockIdx == block_id)

            # Get all trials from this block
            block_trials = [np.concatenate([spikePow[j][:, area6v_indices], tx1[j][:, area6v_indices]], axis=1)
                            for j in range(num_trials) if block_mask[j]]

            # Stack all block trials to compute mean & std
            block_data = np.vstack(block_trials)
            mean = block_data.mean(axis=0)
            std = block_data.std(axis=0) + 1e-8  # avoid divide by zero

            # z-score the current trial
            trial_features = (trial_features - mean) / std

            # Extract sentenceText (handle both string and char matrix cases)
            sentence_entry = sentenceText[i]
            if isinstance(sentence_entry, np.ndarray):
                sentence = ''.join(chr(int(c)) for c in sentence_entry.flatten() if c != 0)
            elif isinstance(sentence_entry, str):
                sentence = sentence_entry
            else:
                sentence = str(sentence_entry)

            X.append(trial_features)
            y.append(sentence)


# Let's check one sample
print("✅ Done extracting.")
print("Sample feature shape:", X[0].shape)
print("Sample label:", y[0])
print("Total examples:", len(X))
# Out:
# ✅ Done extracting.
# Sample feature shape: (478, 256)
# Sample label: Nuclear rockets can destroy airfields with ease.
# Total examples: 8800

# %% [markdown]
# 🧠 Step 4: Pad Sequences & Encode Labels
# Your features X are variable-length sequences (trials), so we need to pad them to the same length. And the labels y are sentences (strings), so we’ll tokenize and encode them as sequences of integers too.
#
# Here’s what we’ll do:
#
# Pad X sequences to the same length.
#
# Create a character-level tokenizer for y.
#
# Convert y into sequences of integers.
#
# Pad y sequences to the same max length.

# %%
# Pad input sequences (X)
max_timesteps = max(x.shape[0] for x in X)
feature_dim = X[0].shape[1]  # Should be 20
print(f"Max timesteps: {max_timesteps}, Feature dim: {feature_dim}")
X_padded = np.array([
    np.pad(x, ((0, max_timesteps - x.shape[0]), (0, 0)), mode='constant')
    for x in X
])

# Tokenize output sequences (y) at character level
tokenizer = Tokenizer(char_level=True)
tokenizer.fit_on_texts(y)
y_sequences = tokenizer.texts_to_sequences(y)

# Pad output sequences (y)
max_label_len = max(len(seq) for seq in y_sequences)
y_padded = pad_sequences(y_sequences, maxlen=max_label_len, padding='post')

# Optional: print shape info
print(f"Padded input shape: {X_padded.shape}")  # (num_samples, max_timesteps, 20)
print(f"Padded labels shape: {y_padded.shape}")  # (num_samples, max_label_len)
print(f"Vocab size: {len(tokenizer.word_index) + 1}")  # +1 for padding index 0
# Out:
# Max timesteps: 906, Feature dim: 256
# Padded input shape: (8800, 906, 256)
# Padded labels shape: (8800, 88)
# Vocab size: 37

# %%
# Parameters
latent_dim = 256  # Size of LSTM hidden states
vocab_size = len(tokenizer.word_index) + 1  # Number of unique characters + padding

# Encoder
encoder_inputs = Input(shape=(max_timesteps, feature_dim))
encoder_lstm = LSTM(latent_dim, return_sequences=False, return_state=True)
_, state_h, state_c = encoder_lstm(encoder_inputs)
encoder_states = [state_h, state_c]

# Decoder
decoder_inputs = Input(shape=(max_label_len,))  # input: padded character sequences
decoder_embedding = Embedding(input_dim=vocab_size, output_dim=latent_dim, mask_zero=True)(decoder_inputs)
decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=False)
decoder_outputs = decoder_lstm(decoder_embedding, initial_state=encoder_states)
decoder_dense = TimeDistributed(Dense(vocab_size, activation='softmax'))
decoder_outputs = decoder_dense(decoder_outputs)

# Full model
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

# Compile
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Summary
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 88)]         0           []
#
#  input_1 (InputLayer)           [(None, 906, 256)]   0           []
#
#  embedding (Embedding)          (None, 88, 256)      9472        ['input_2[0][0]']
#
#  lstm (LSTM)                    [(None, 256),        525312      ['input_1[0][0]']
#                                  (None, 256),
#                                  (None, 256)]
#
#  lstm_1 (LSTM)                  (None, 88, 256)      525312      ['embedding[0][0]',
#                                                                   'lstm[0][1]',
#                                                                   'lstm[0][2]']
#
#  time_distributed (TimeDistribu  (None, 88, 37)      9509        ['lstm_1[0][0]']
#  ted)
#
# ==================================================================================================
# Total params: 1,069,605
# Trainable params: 1,069,605
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Compile the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Shift y_padded by one timestep for decoder output
decoder_target_data = np.expand_dims(y_padded, -1)  # (num_samples, max_label_len, 1)

# Train the model
history = model.fit(
    [X_padded, y_padded], decoder_target_data,
    batch_size=64,
    epochs=20,
    validation_split=0.1
)
# Out:
# Epoch 1/20
# 124/124 [==============================] - 254s 2s/step - loss: 1.2436 - accuracy: 0.7211 - val_loss: 0.1836 - val_accuracy: 0.9923
# Epoch 2/20
# 124/124 [==============================] - 243s 2s/step - loss: 0.0390 - accuracy: 0.9979 - val_loss: 0.0083 - val_accuracy: 0.9999
# Epoch 3/20
# 124/124 [==============================] - 246s 2s/step - loss: 0.0056 - accuracy: 0.9997 - val_loss: 0.0028 - val_accuracy: 1.0000
# Epoch 4/20
# 124/124 [==============================] - 245s 2s/step - loss: 0.0025 - accuracy: 0.9999 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 5/20
# 124/124 [==============================] - 251s 2s/step - loss: 0.0015 - accuracy: 0.9999 - val_loss: 9.3442e-04 - val_accuracy: 1.0000
# Epoch 6/20
# 124/124 [==============================] - 244s 2s/step - loss: 9.9498e-04 - accuracy: 0.9999 - val_loss: 6.5456e-04 - val_accuracy: 1.0000
# Epoch 7/20
# 124/124 [==============================] - 251s 2s/step - loss: 7.0546e-04 - accuracy: 1.0000 - val_loss: 4.8938e-04 - val_accuracy: 1.0000
# Epoch 8/20
# 124/124 [==============================] - 263s 2s/step - loss: 5.1336e-04 - accuracy: 1.0000 - val_loss: 3.8021e-04 - val_accuracy: 1.0000
# Epoch 9/20
# 124/124 [==============================] - 264s 2s/step - loss: 3.8192e-04 - accuracy: 1.0000 - val_loss: 3.0339e-04 - val_accuracy: 1.0000
# Epoch 10/20
# 124/124 [==============================] - 259s 2s/step - loss: 2.9468e-04 - accuracy: 1.0000 - val_loss: 2.4817e-04 - val_accuracy: 1.0000
# Epoch 11/20
# 124/124 [==============================] - 278s 2s/step - loss: 2.3728e-04 - accuracy: 1.0000 - val_loss: 2.0521e-04 - val_accuracy: 1.0000
# Epoch 12/20
# 124/124 [==============================] - 263s 2s/step - loss: 1.9487e-04 - accuracy: 1.0000 - val_loss: 1.7286e-04 - val_accuracy: 1.0000
# Epoch 13/20
# 124/124 [==============================] - 264s 2s/step - loss: 1.6329e-04 - accuracy: 1.0000 - val_loss: 1.4767e-04 - val_accuracy: 1.0000
# Epoch 14/20
# 124/124 [==============================] - 262s 2s/step - loss: 1.3907e-04 - accuracy: 1.0000 - val_loss: 1.2742e-04 - val_accuracy: 1.0000
# Epoch 15/20
# 124/124 [==============================] - 263s 2s/step - loss: 1.1971e-04 - accuracy: 1.0000 - val_loss: 1.1118e-04 - val_accuracy: 1.0000
# Epoch 16/20
# 124/124 [==============================] - 262s 2s/step - loss: 1.0412e-04 - accuracy: 1.0000 - val_loss: 9.7410e-05 - val_accuracy: 1.0000
# Epoch 17/20
# 124/124 [==============================] - 264s 2s/step - loss: 9.1288e-05 - accuracy: 1.0000 - val_loss: 8.6135e-05 - val_accuracy: 1.0000
# Epoch 18/20
# 124/124 [==============================] - 266s 2s/step - loss: 8.0688e-05 - accuracy: 1.0000 - val_loss: 7.6633e-05 - val_accuracy: 1.0000
# Epoch 19/20
# 124/124 [==============================] - 254s 2s/step - loss: 7.1738e-05 - accuracy: 1.0000 - val_loss: 6.8540e-05 - val_accuracy: 1.0000
# Epoch 20/20
# 124/124 [==============================] - 254s 2s/step - loss: 6.4130e-05 - accuracy: 1.0000 - val_loss: 6.1500e-05 - val_accuracy: 1.0000

# %%
import numpy as np
import os
import scipy.io

def load_test_data(test_folder):
    # Area 6v only
    area6v_indices = np.arange(0, 128)

    X_test = []
    y_test = []

    for filename in os.listdir(test_folder):
        if filename.endswith('.mat'):
            file_path = os.path.join(test_folder, filename)
            mat = scipy.io.loadmat(file_path)

            spikePow = mat['spikePow'].squeeze()
            tx1 = mat['tx1'].squeeze()
            blockIdx = mat['blockIdx'].squeeze()
            sentenceText = mat['sentenceText']

            num_trials = len(spikePow)

            for i in range(num_trials):
                # Extract spikePow and tx1 for this trial (only Area 6v)
                spike_trial = spikePow[i][:, area6v_indices]
                tx1_trial = tx1[i][:, area6v_indices]

                # Concatenate features (T x 256)
                trial_features = np.concatenate([spike_trial, tx1_trial], axis=1)

                # Normalize with block-wise mean and std
                block_id = blockIdx[i]
                block_mask = (blockIdx == block_id)

                block_trials = [np.concatenate([spikePow[j][:, area6v_indices], tx1[j][:, area6v_indices]], axis=1)
                                for j in range(num_trials) if block_mask[j]]

                block_data = np.vstack(block_trials)
                mean = block_data.mean(axis=0)
                std = block_data.std(axis=0) + 1e-8

                trial_features = (trial_features - mean) / std

                # Decode sentence text
                sentence_entry = sentenceText[i]
                if isinstance(sentence_entry, np.ndarray):
                    sentence = ''.join(chr(int(c)) for c in sentence_entry.flatten() if c != 0)
                elif isinstance(sentence_entry, str):
                    sentence = sentence_entry
                else:
                    sentence = str(sentence_entry)

                X_test.append(trial_features)
                y_test.append(sentence)

    return X_test, y_test


# Load
X_test, y_test = load_test_data('dataset/test')
print("✅ Done loading.")
print("Test samples:", len(X_test))
print("First input shape:", X_test[0].shape)
print("First label:", y_test[0])
# Out:
# ✅ Done loading.
# Test samples: 880
# First input shape: (254, 256)
# First label: Theocracy reconsidered.

# %%
# Pad
X_test_padded = np.array([
    x[:max_timesteps] if x.shape[0] >= max_timesteps else np.pad(x, ((0, max_timesteps - x.shape[0]), (0, 0)), mode='constant')
    for x in X_test
])


y_test_sequences = tokenizer.texts_to_sequences(y_test)
y_test_padded = pad_sequences(y_test_sequences, maxlen=max_label_len, padding='post')
decoder_target_test = np.expand_dims(y_test_padded, -1)

# Evaluate
model.evaluate([X_test_padded, y_test_padded], decoder_target_test, batch_size=64)
# Out:
# 14/14 [==============================] - 7s 508ms/step - loss: 6.4578e-05 - accuracy: 1.0000
# [6.45776090095751e-05, 1.0]

# %%
predictions = model.predict([X_test_padded, y_test_padded])
predicted_token_ids = np.argmax(predictions, axis=-1)  # shape: (batch_size, seq_len)

decoded_sentences = tokenizer.sequences_to_texts(predicted_token_ids)
for pred, true in zip(decoded_sentences, y_test):
    print(f"Prediction: {pred}")
    print(f"Ground Truth: {true}")
    print("-" * 50)
# Out:
# 28/28 [==============================] - 11s 337ms/step
# Prediction: t h e o c r a c y   r e c o n s i d e r e d .
# Ground Truth: Theocracy reconsidered.
# --------------------------------------------------
# Prediction: r i c h   p u r c h a s e d   s e v e r a l   s i g n e d   l i t h o g r a p h s .
# Ground Truth: Rich purchased several signed lithographs.
# --------------------------------------------------
# Prediction: s o   r u l e s   w e   m a d e ,   i n   u n a b a s h e d   c o l l u s i o n .
# Ground Truth: So rules we made, in unabashed collusion.
# --------------------------------------------------
# Prediction: l o r i ' s   c o s t u m e   n e e d e d   b l a c k   g l o v e s   t o   b e   c o m p l e t e l y   e l e g a n t .
# Ground Truth: Lori's costume needed black gloves to be completely elegant.
# --------------------------------------------------
# Prediction: t h e   t o o t h   f a i r y   f o r g o t   t o   c o m e   w h e n   r o g e r ' s   t o o t h   f e l l   o u t .
# Ground Truth: The tooth fairy forgot to come when Roger's tooth fell out.
# --------------------------------------------------
# Prediction: t h a t   s t i n g i n g   v a p o r   w a s   c a u s e d   b y   c h l o r i d e   v a p o r i z a t i o n .
# Ground Truth: That stinging vapor was caused by chloride vaporization.
# --------------------------------------------------
# Prediction: b e f o r e   t h u r s d a y ' s   e x a m ,   r e v i e w   e v e r y   f o r m u l a .
# Ground Truth: Before Thursday's exam, review every formula.
# --------------------------------------------------
# Prediction: w i l d f i r e   n e a r   s u n s h i n e   f o r c e s   p a r k   c l o s u r e s .
# Ground Truth: Wildfire near Sunshine forces park closures.
# --------------------------------------------------
# Prediction: t h e   w o r d   m e a n s   i t   w o n ' t   b o i l   a w a y   e a s i l y ,   n o t h i n g   e l s e .
# Ground Truth: The word means it won't boil away easily, nothing else.
# --------------------------------------------------
# Prediction: w o u l d   a   b l u e   f e a t h e r   i n   a   m a n ' s   h a t   m a k e   h i m   h a p p y   a l l   d a y ?
# Ground Truth: Would a blue feather in a man's hat make him happy all day?
# --------------------------------------------------
# Prediction: h e   t a l k e d   a b o u t   u n a u t h e n t i c   s t o r y l i n e s   t o o .
# Ground Truth: He talked about unauthentic storylines too.
# --------------------------------------------------
# Prediction: m o s t   y o u n g   r i s e   e a r l y   e v e r y   m o r n i n g .
# Ground Truth: Most young rise early every morning.
# --------------------------------------------------
# Prediction: w i t h   t h i s   n o   l o y a l   c i t i z e n   c a n   q u a r r e l .
# Ground Truth: With this no loyal citizen can quarrel.
# --------------------------------------------------
# Prediction: p r i m i t i v e   t r i b e s   h a v e   a n   u p b e a t   a t t i t u d e .
# Ground Truth: Primitive tribes have an upbeat attitude.
# --------------------------------------------------
# Prediction: a n d   i t   w a s   n o t   a   j u d g e ,   b u t   a   j u s t i c e   o f   t h e   p e a c e   w h o   m a d e   t h e   d e c i s i o n .
# Ground Truth: And it was not a judge, but a justice of the peace who made the decision.
# --------------------------------------------------
# Prediction: w e   s e e m e d   t o   b e   w i t n e s s i n g   t h e   p o p u l a t i o n   e x p l o s i o n   r i g h t   i n   o u r   o w n   b a c k y a r d s .
# Ground Truth: We seemed to be witnessing the population explosion right in our own backyards.
# --------------------------------------------------
# Prediction: s o m e t i m e s ,   d e s p e r a t e   m e a s u r e s   c a n   a l s o   t u r n   i n t o   s o l i d   m o v e s   f o r   t h e   f u t u r e .
# Ground Truth: Sometimes, desperate measures can also turn into solid moves for the future.
# --------------------------------------------------
# Prediction: t h o s e   a n s w e r s   w i l l   b e   s t r a i g h t f o r w a r d   i f   y o u   t h i n k   t h e m   t h r o u g h   c a r e f u l l y   f i r s t . . . . . . . . .
# Ground Truth: Those answers will be straightforward if you think them through carefully first.
# --------------------------------------------------
# Prediction: s h e   g e t s   d r e s s e d   f a s t e r   a n d   s p e n d s   l e s s   e n e r g y   m a k i n g   c l o t h i n g   d e c i s i o n s .
# Ground Truth: She gets dressed faster and spends less energy making clothing decisions.
# --------------------------------------------------
# Prediction: a c a d e m i c   a p t i t u d e   g u a r a n t e e s   y o u r   d i p l o m a .
# Ground Truth: Academic aptitude guarantees your diploma.
# --------------------------------------------------
# Prediction: t o   s o m e   e x t e n t   p r e d i s p o s i t i o n s   a r e   s h a p e d   b y   e x p o s u r e   t o   g r o u p   e n v i r o n m e n t s .
# Ground Truth: To some extent predispositions are shaped by exposure to group environments.
# --------------------------------------------------
# Prediction: a n   a d u l t   m a l e   b a b o o n ' s   t e e t h   a r e   n o t   s u i t a b l e   f o r   e a t i n g   s h e l l f i s h .
# Ground Truth: An adult male baboon's teeth are not suitable for eating shellfish.
# --------------------------------------------------
# Prediction: i n   t h i s   c o n t e x t ,   i t   w o u l d   d o   w e l l   f o r   u s   t o   b e a r   i n   m i n d   t h e   v i s i o n   o f   p e a c e .
# Ground Truth: In this context, it would do well for us to bear in mind the vision of peace.
# --------------------------------------------------
# Prediction: y o u ' r e   b o i l i n g   m i l k ,   a i n ' t   y o u ?
# Ground Truth: You're boiling milk, ain't you?
# --------------------------------------------------
# Prediction: r i c h   l o o k e d   f o r   s p o t t e d   h y e n a s   a n d   j a g u a r s   o n   t h e   s a f a r i .
# Ground Truth: Rich looked for spotted hyenas and jaguars on the safari.
# --------------------------------------------------
# Prediction: t r a f f i c   f r e q u e n t l y   h a s   f a i l e d   t o   m e a s u r e   u p   t o   e n g i n e e r s '   r o s y   e s t i m a t e s .
# Ground Truth: Traffic frequently has failed to measure up to engineers' rosy estimates.
# --------------------------------------------------
# Prediction: r a l p h   p r e p a r e d   r e d   s n a p p e r   w i t h   f r e s h   l e m o n   s a u c e   f o r   d i n n e r .
# Ground Truth: Ralph prepared red snapper with fresh lemon sauce for dinner.
# --------------------------------------------------
# Prediction: d i d   y o u   b u y   a n y   c o r d u r o y   o v e r a l l s ?
# Ground Truth: Did you buy any corduroy overalls?
# --------------------------------------------------
# Prediction: c l e a r   p r o n u n c i a t i o n   i s   a p p r e c i a t e d .
# Ground Truth: Clear pronunciation is appreciated.
# --------------------------------------------------
# Prediction: p l e a s e   s h o r t e n   t h i s   s k i r t   f o r   j o y c e .
# Ground Truth: Please shorten this skirt for Joyce.
# --------------------------------------------------
# Prediction: w h o   a u t h o r i z e d   t h e   u n l i m i t e d   e x p e n s e   a c c o u n t ?
# Ground Truth: Who authorized the unlimited expense account?
# --------------------------------------------------
# Prediction: t h e   f a m i l y   r e q u e s t s   t h a t   f l o w e r s   b e   o m i t t e d .
# Ground Truth: The family requests that flowers be omitted.
# --------------------------------------------------
# Prediction: t h e   m u s e u m   h i r e s   m u s i c i a n s   e v e r y   e v e n i n g .
# Ground Truth: The museum hires musicians every evening.
# --------------------------------------------------
# Prediction: w e ' l l   s e r v e   r h u b a r b   p i e   a f t e r   r a c h e l ' s   t a l k .
# Ground Truth: We'll serve rhubarb pie after Rachel's talk.
# --------------------------------------------------
# Prediction: t h e y   e n j o y   i t   w h e n   i   a u d i t i o n .
# Ground Truth: They enjoy it when I audition.
# --------------------------------------------------
# Prediction: t h e   a v o c a d o   s h o u l d   h a v e   a   g i v e   t o   i t ,   a s   y o u   h o l d   i t ,   w h e n   i t   i s   r i p e .
# Ground Truth: The avocado should have a give to it, as you hold it, when it is ripe.
# --------------------------------------------------
# Prediction: e n e r g y   s u p p l i e r s   u s u a l l y   d e a l   w i t h   t h i s   b y   c o n d u c t i n g   r e g u l a r   i n s p e c t i o n s   a n d   t r i m m i n g . .
# Ground Truth: Energy suppliers usually deal with this by conducting regular inspections and trimming.
# --------------------------------------------------
# Prediction: t h e   s a w   i s   b r o k e n ,   s o   c h o p   t h e   w o o d   i n s t e a d .
# Ground Truth: The saw is broken, so chop the wood instead.
# --------------------------------------------------
# Prediction: t h e   c l e a n e d   v e r s i o n   i s   g i v e n   b e l o w .
# Ground Truth: The cleaned version is given below.
# --------------------------------------------------
# Prediction: t h e y   s e e m   d a r n e d   p r o u d   o f   i t .
# Ground Truth: They seem darned proud of it.
# --------------------------------------------------
# Prediction: a   s h a r p   t r e m o r   w a s   f o l l o w e d   b y   a   j e r k y   r o l l .
# Ground Truth: A sharp tremor was followed by a jerky roll.
# --------------------------------------------------
# Prediction: b o y ,   y o u   a i n ' t   f o o l i n g   n o b o d y   b u t   y o u r s e l f .
# Ground Truth: Boy, you ain't fooling nobody but yourself.
# --------------------------------------------------
# Prediction: t e a c h i n g   g u i d e s   a r e   i n c l u d e d   w i t h   e a c h   r e c o r d . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Ground Truth: Teaching guides are included with each record.
# --------------------------------------------------
# Prediction: t h e   m a n ' s   e y e l i d s   f l u t t e r e d .
# Ground Truth: The man's eyelids fluttered.
# --------------------------------------------------
# Prediction: t h i s   k i d ' s   f r o z e   b a d .
# Ground Truth: This kid's froze bad.
# --------------------------------------------------
# Prediction: s h e   r a d i a t e d   w a r m t h   a n d   g o o d   f e l l o w s h i p .
# Ground Truth: She radiated warmth and good fellowship.
# --------------------------------------------------
# Prediction: d o   y o u   k n o w   w h e r e   i t   m i g h t   h a v e   g o n e ?
# Ground Truth: Do you know where it might have gone?
# --------------------------------------------------
# Prediction: i n   t h e   p i t y   f o r   t h e m   h i s   l o n e l i n e s s   w a s   g o n e .
# Ground Truth: In the pity for them his loneliness was gone.
# --------------------------------------------------
# Prediction: j o i n   u s   o n   t w i t t e r   a n d   f a c e b o o k
# Ground Truth: Join us on Twitter and Facebook
# --------------------------------------------------
# Prediction: h e   s a i d   t h e y ' l l   b e   w o r k i n g   t o w a r d   a   d e c i s i o n .
# Ground Truth: He said they'll be working toward a decision.
# --------------------------------------------------
# Prediction: s h a v i n g   c r e a m   i s   a   p o p u l a r   i t e m   o n   h a l l o w e e n .
# Ground Truth: Shaving cream is a popular item on Halloween.
# --------------------------------------------------
# Prediction: t h e n   s i m m e r   f i f t e e n   m i n u t e s   l o n g e r .
# Ground Truth: Then simmer fifteen minutes longer.
# --------------------------------------------------
# Prediction: a   t h i r d   s h o t   d o u s e d   t h e   l i g h t .
# Ground Truth: A third shot doused the light.
# --------------------------------------------------
# Prediction: t h e   g u t t u r a l   l a n g u a g e   f r o m   t h e   g h e t t o   s t o p p e d . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Ground Truth: The guttural language from the ghetto stopped.
# --------------------------------------------------
# Prediction: l i k e   a s   i f   i t   w e r e   b u i l t   o f   b o o k s .
# Ground Truth: Like as if it were built of books.
# --------------------------------------------------
# Prediction: t h e n   h e   - -   t h e n   w h a t ?
# Ground Truth: Then he -- then what?
# --------------------------------------------------
# Prediction: i   a m   a n   a r t i s t ,   l o s t   i n   m y   o w n   v i s i o n .
# Ground Truth: I am an artist, lost in my own vision.
# --------------------------------------------------
# Prediction: b l o c k a d e   i s   o n e   a n s w e r   o f f e r e d   b y   e x p e r t s .
# Ground Truth: Blockade is one answer offered by experts.
# --------------------------------------------------
# Prediction: t h o s e   m u s i c i a n s   h a r m o n i z e   m a r v e l o u s l y .
# Ground Truth: Those musicians harmonize marvelously.
# --------------------------------------------------
# Prediction: i t   a l l   d i d   l o o k   v e r y   e f f i c i e n t   a n d   s h i p s h a p e .
# Ground Truth: It all did look very efficient and shipshape.
# --------------------------------------------------
# Prediction: y e t   w e   n o   l o n g e r   f e e l   u n e a s y .
# Ground Truth: Yet we no longer feel uneasy.
# --------------------------------------------------
# Prediction: i n f l a m m a t o r y   c e l l s   w e r e   s t r i k i n g l y   a b s e n t .
# Ground Truth: Inflammatory cells were strikingly absent.
# --------------------------------------------------
# Prediction: i t   c a n   p r o j e c t   l o n g - r a n g e   g o a l s   f o r   i t s e l f .
# Ground Truth: It can project long-range goals for itself.
# --------------------------------------------------
# Prediction: i n t e l l i g e n c e   j a b b e d   a t   h i m   a c c u s i n g l y .
# Ground Truth: Intelligence jabbed at him accusingly.
# --------------------------------------------------
# Prediction: d o   y o u   h e a r   t h e   s l e i g h   b e l l s   r i n g i n g ?
# Ground Truth: Do you hear the sleigh bells ringing?
# --------------------------------------------------
# Prediction: t h e r e   w a s   m u c h   e m b r a c i n g ,   m u c h   e x c l a i m i n g .
# Ground Truth: There was much embracing, much exclaiming.
# --------------------------------------------------
# Prediction: b e l o w   i s   a   s p e c i f i c   g u i d e ,   k e y e d   t o   t h e   c a l e n d a r . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Ground Truth: Below is a specific guide, keyed to the calendar.
# --------------------------------------------------
# Prediction: f i n a l l y   h e   a s k e d ,   d o   y o u   o b j e c t   t o   p e t t i n g ?
# Ground Truth: Finally he asked, do you object to petting?
# --------------------------------------------------
# Prediction: w e ' l l   p a y   y o u   b a c k   i f   y o u ' l l   l e t   u s .
# Ground Truth: We'll pay you back if you'll let us.
# --------------------------------------------------
# Prediction: t h e y   c l o s e   s o m e t i m e   a f t e r   e i g h t .
# Ground Truth: They close sometime after eight.
# --------------------------------------------------
# Prediction: t h e n   w e   w e r e   o f f   a g a i n .
# Ground Truth: Then we were off again.
# --------------------------------------------------
# Prediction: h i s   w i f e   d i d n ' t   g i v e   a   s i g n   s h e ' d   h e a r d .
# Ground Truth: His wife didn't give a sign she'd heard.
# --------------------------------------------------
# Prediction: f o r   a   m a n   o f   h i s   m a s s   h e   w a s   c u r i o u s l y   s h o r t .
# Ground Truth: For a man of his mass he was curiously short.
# --------------------------------------------------
# Prediction: p a m   g i v e s   d r i v i n g   l e s s o n s   o n   t h u r s d a y s .
# Ground Truth: Pam gives driving lessons on Thursdays.
# --------------------------------------------------
# Prediction: r e a d   t h e   d e c i s i o n   b e l o w .
# Ground Truth: Read the decision below.
# --------------------------------------------------
# Prediction: r e c e i v i n g   n o   a n s w e r ,   t h e y   s e t   t h e   f i r e .
# Ground Truth: Receiving no answer, they set the fire.
# --------------------------------------------------
# Prediction: w h e r e   i s   y o u r   u s u a l   u p b e a t   p e r s o n a l i t y ?
# Ground Truth: Where is your usual upbeat personality?
# --------------------------------------------------
# Prediction: n i c e   c o u n t r y   t o   m e e t   a   l i o n   i n   f a c e   t o   f a c e .
# Ground Truth: Nice country to meet a lion in face to face.
# --------------------------------------------------
# Prediction: w i t h   a   w h i r l i n g   j u m p ,   i t   c o u l d   g e t   i n t o   g e a r .
# Ground Truth: With a whirling jump, it could get into gear.
# --------------------------------------------------
# Prediction: m a r k s m a n s h i p   e x a m p l e .
# Ground Truth: Marksmanship example.
# --------------------------------------------------
# Prediction: i t ' s   r e a l l y   h a r d   t o   f i n d   s o m e t h i n g   t h a t   w o r k s .
# Ground Truth: It's really hard to find something that works.
# --------------------------------------------------
# Prediction: a n d   i   l o v e d   t h s   s h i n i n g .
# Ground Truth: And I loved ths shining.
# --------------------------------------------------
# Prediction: i   d o   h a v e   a   f r i e n d   t h a t   r a n .
# Ground Truth: I do have a friend that ran.
# --------------------------------------------------
# Prediction: j u s t   w a y   i n   t h e   b a c k .
# Ground Truth: Just way in the back.
# --------------------------------------------------
# Prediction: a c t u a l l y ,   i t   m a k e s   s e n s e   t o   a   c e r t a i n   e x t e n t .
# Ground Truth: Actually, it makes sense to a certain extent.
# --------------------------------------------------
# Prediction: a s s u r e   t h e   g o v e r n m e n t   t h a t   h e   w a s   e m p l o y e d .
# Ground Truth: Assure the government that he was employed.
# --------------------------------------------------
# Prediction: t h e y   f e e l   g o o d   a b o u t   w h a t   t h e y ' r e   d o i n g .
# Ground Truth: They feel good about what they're doing.
# --------------------------------------------------
# Prediction: b e s i d e s ,   i t s   a n   i n v a s i o n   o f   p e r s o n a l   p r i v a c y .
# Ground Truth: Besides, its an invasion of personal privacy.
# --------------------------------------------------
# Prediction: s o   y o u   t r a v e l   a   l o t ?
# Ground Truth: So you travel a lot?
# --------------------------------------------------
# Prediction: s o   w e ' r e   g o i n g   t o   w a i t .
# Ground Truth: So we're going to wait.
# --------------------------------------------------
# Prediction: a n y   k i n d   o f   a   g o o d   e n v i r o n m e n t   t o   l i v e   i n .
# Ground Truth: Any kind of a good environment to live in.
# --------------------------------------------------
# Prediction: t h e   b e s t   o f   a n d r o i d .
# Ground Truth: The best of Android.
# --------------------------------------------------
# Prediction: i   d o n ' t   k n o w   w h a t   y o u   t h i n k   a b o u t   t h e   p o i n t .
# Ground Truth: I don't know what you think about the point.
# --------------------------------------------------
# Prediction: i   b e l i e v e   i t   c o s t s   a b o u t   t e n   d o l l a r s .
# Ground Truth: I believe it costs about ten dollars.
# --------------------------------------------------
# Prediction: w h a t   i n   t h e   w o r l d   d r u g s   a r e   y o u   o n   t o ?
# Ground Truth: What in the world drugs are you on to?
# --------------------------------------------------
# Prediction: a n d r o i d   t v   b o x .
# Ground Truth: Android TV box.
# --------------------------------------------------
# Prediction: a   c o u p l e   o f   t i m e s .
# Ground Truth: A couple of times.
# --------------------------------------------------
# Prediction: i   h a d   t h e   b r a k e s   d o n e   o n   i t .
# Ground Truth: I had the brakes done on it.
# --------------------------------------------------
# Prediction: w h i c h   i   u s e   a s   a   r e f e r e n c e   a n d   h a s   b e e n   r e a l   h a n d y . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Ground Truth: Which I use as a reference and has been real handy.
# --------------------------------------------------
# Prediction: i   k n o w   w h e n   i   w a s   w o r k i n g .
# Ground Truth: I know when I was working.
# --------------------------------------------------
# Prediction: i t ' s   a   p a c k a g e   d e a l .
# Ground Truth: It's a package deal.
# --------------------------------------------------
# Prediction: i   h a v e   s e e n   i t .
# Ground Truth: I have seen it.
# --------------------------------------------------
# Prediction: t h e   m e a s u r e s   a l r e a d y   p a s s e d   a   s e n a t e   c o m m i t t e e .
# Ground Truth: The measures already passed a Senate committee.
# --------------------------------------------------
# Prediction: t h e y   t o l d   m e   t h a t   t h i s   w a s   a   t o p i c .
# Ground Truth: They told me that this was a topic.
# --------------------------------------------------
# Prediction: i n   t h e   r e d   s q u a r e   o r   w h e r e v e r   s a i d .
# Ground Truth: In the Red Square or wherever said.
# --------------------------------------------------
# Prediction: t h e y   d i d   a   l o t   o f   p l a y   w o r k   a n d   s t u f f .
# Ground Truth: They did a lot of play work and stuff.
# --------------------------------------------------
# Prediction: y o u   c a n   g a i n   t o o   m u c h   w e i g h t .
# Ground Truth: You can gain too much weight.
# --------------------------------------------------
# Prediction: r e c e n t   l e g i s l a t i o n .
# Ground Truth: Recent legislation.
# --------------------------------------------------
# Prediction: i ' m   a   c a r   b u f f   t o o .
# Ground Truth: I'm a car buff too.
# --------------------------------------------------
# Prediction: j o y   s p r i n g s   f r o m   a   g r a t e f u l   h e a r t .
# Ground Truth: Joy springs from a grateful heart.
# --------------------------------------------------
# Prediction: c h a r   o n i o n   o v e r   g r i l l ,   n e v e r   a l l o w   o i l   t o   s m o k e .
# Ground Truth: Char onion over grill, never allow oil to smoke.
# --------------------------------------------------
# Prediction: n o i s e   c a u s e s   a i r   p o l l u t i o n .
# Ground Truth: Noise causes air pollution.
# --------------------------------------------------
# Prediction: a n d   t h e n   y o u   s p r i n k l e   t h e   c h e e s e   o n   t o p   o f   t h a t .
# Ground Truth: And then you sprinkle the cheese on top of that.
# --------------------------------------------------
# Prediction: j u s t   s a y i n g   t h a t   c l e a r   v i s i o n   i s   a   n e c e s s i t y .
# Ground Truth: Just saying that clear vision is a necessity.
# --------------------------------------------------
# Prediction: f a c t o r s   t h a t   a f f e c t   e a r n i n g s   o f   a n   e m p l o y e e .
# Ground Truth: Factors that affect earnings of an employee.
# --------------------------------------------------
# Prediction: i f   y o u   d r i n k   a   l o t   o f   c a f f e i n e   y o u ' l l   s t a y   a w a k e .
# Ground Truth: If you drink a lot of caffeine you'll stay awake.
# --------------------------------------------------
# Prediction: t h a t ' s   a   n i c e   c a r .
# Ground Truth: That's a nice car.
# --------------------------------------------------
# Prediction: v i s i o n a r y   l e a d e r s .
# Ground Truth: Visionary leaders.
# --------------------------------------------------
# Prediction: t h e   o n l y   o t h e r   p l a c e   i ' v e   e v e r   v a c a t i o n e d .
# Ground Truth: The only other place I've ever vacationed.
# --------------------------------------------------
# Prediction: i   j u s t   k i n d   o f   w e n t   t h r o u g h .
# Ground Truth: I just kind of went through.
# --------------------------------------------------
# Prediction: t h i s   i s   u n i f y i n g   v o i c e   w e   n e e d .
# Ground Truth: This is unifying voice we need.
# --------------------------------------------------
# Prediction: d o   y o u   h a v e   y o u r   b a g ?
# Ground Truth: Do you have your bag?
# --------------------------------------------------
# Prediction: s o   y o u   k n o w   i t   k e e p s   u s   p r e t t y   b u s y .
# Ground Truth: So you know it keeps us pretty busy.
# --------------------------------------------------
# Prediction: t h a t ' s   a   s c i e n c e   i n   i t s e l f .
# Ground Truth: That's a science in itself.
# --------------------------------------------------
# Prediction: s o   w h e n   y o u   g e t   i n   t i g h t   s i t u a t i o n s ?
# Ground Truth: So when you get in tight situations?
# --------------------------------------------------
# Prediction: i   c a n   r e l a t e   t o   t h a t .
# Ground Truth: I can relate to that.
# --------------------------------------------------
# Prediction: i t ' s   a l l   r e a d y   q u i t   p l a y i n g .
# Ground Truth: It's all ready quit playing.
# --------------------------------------------------
# Prediction: i f   t h e y ' r e   a r o u n d   a n y m o r e .
# Ground Truth: If they're around anymore.
# --------------------------------------------------
# Prediction: i   a m   n o t   e v e n   a w a r e   t h a t   i   c o u l d   h a v e   s e e n   i t .
# Ground Truth: I am not even aware that I could have seen it.
# --------------------------------------------------
# Prediction: t h e   r a n k s   o f   a s i a n   r i d e r s   a r e   s w e l l i n g   t o o .
# Ground Truth: The ranks of Asian riders are swelling too.
# --------------------------------------------------
# Prediction: e i n s t e i n   e q u a t i o n .
# Ground Truth: Einstein equation.
# --------------------------------------------------
# Prediction: m o s t   p o i n t s   a t   t h e   e n d   w i n s !
# Ground Truth: Most points at the end wins!
# --------------------------------------------------
# Prediction: i   t h i n k   i t ' s   o n e   h u n d r e d   a n d   e i g h t y   m i l e s .
# Ground Truth: I think it's one hundred and eighty miles.
# --------------------------------------------------
# Prediction: w e   d o n ' t   u s u a l l y   t a k e   t h e   k i d s   w h e n   w e   g o   t h e r e .
# Ground Truth: We don't usually take the kids when we go there.
# --------------------------------------------------
# Prediction: o n e   o f   t h o s e   g e n e r a t i o n   n o v e l s .
# Ground Truth: One of those generation novels.
# --------------------------------------------------
# Prediction: t h e y   ' l l   n e v e r   g e t   c a u g h t .
# Ground Truth: They 'll never get caught.
# --------------------------------------------------
# Prediction: i   d o n ' t   b u y   t h e   n e w s p a p e r .
# Ground Truth: I don't buy the newspaper.
# --------------------------------------------------
# Prediction: b r i n g i n g   s o m e t h i n g   f o r   a   p o t l u c k   p i c n i c .
# Ground Truth: Bringing something for a potluck picnic.
# --------------------------------------------------
# Prediction: i   ' l l   t a k e   i t   o u t .
# Ground Truth: I 'll take it out.
# --------------------------------------------------
# Prediction: i m p r o v e d   e v a s i o n   d o e s   n o t   w o r k .
# Ground Truth: Improved evasion does not work.
# --------------------------------------------------
# Prediction: c a s u a l t i e s   w e r e   r e p o r t e d .
# Ground Truth: Casualties were reported.
# --------------------------------------------------
# Prediction: y o u   j u s t   l i k e   t o   s i t   d o w n   a n d   w a t c h   i t .
# Ground Truth: You just like to sit down and watch it.
# --------------------------------------------------
# Prediction: h e   h e l p s   b y   g i v i n g   l i t t l e   p o i n t e r s .
# Ground Truth: He helps by giving little pointers.
# --------------------------------------------------
# Prediction: c a u s e   t h e y   a l l   g r e w   u p   i n   n e w   y o r k   c i t y .
# Ground Truth: Cause they all grew up in New York City.
# --------------------------------------------------
# Prediction: y o u   m a k e   s u c h   a   c h o i c e .
# Ground Truth: You make such a choice.
# --------------------------------------------------
# Prediction: b u t   t h e y   h a v e   s n a k e s   o v e r   t h e r e .
# Ground Truth: But they have snakes over there.
# --------------------------------------------------
# Prediction: a   g o o d   p o s i t i v e   d i r e c t i o n .
# Ground Truth: A good positive direction.
# --------------------------------------------------
# Prediction: t h a t ' s   w h a t   i   w a s   g o i n g   t o   p o i n t   o u t .
# Ground Truth: That's what I was going to point out.
# --------------------------------------------------
# Prediction: i   t u r n e d   m i n e   i n   a b o u t   t w e l v e   h o u r s   e a r l y   a t   n o o n . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Ground Truth: I turned mine in about twelve hours early at noon.
# --------------------------------------------------
# Prediction: i t ' s   a   t e l e c o m m u n i c a t i o n s   t y p e   o f   c o m p a n y .
# Ground Truth: It's a telecommunications type of company.
# --------------------------------------------------
# Prediction: i   w o r k   o u t   o f   m y   h o m e .
# Ground Truth: I work out of my home.
# --------------------------------------------------
# Prediction: t h e   w a y   i t   w o r k s .
# Ground Truth: The way it works.
# --------------------------------------------------
# Prediction: i t   d o e s n ' t   h a v e   a n   a i r   c o n d i t i o n e r .
# Ground Truth: It doesn't have an air conditioner.
# --------------------------------------------------
# ...
# Ground Truth: Just a little shell to go under a suit.
# --------------------------------------------------
# Prediction: t h e n   w e   p u t   o u r   r e c e i p t s   i n   t h e r e .
# Ground Truth: Then we put our receipts in there.
# --------------------------------------------------
# Prediction: w h e r e   i s   i t   g o i n g   t o   b e ?
# Ground Truth: Where is it going to be?
# --------------------------------------------------
# Prediction: f i f t y   n i n e   k i l o m e t e r s   p e r   g a l l o n .
# Ground Truth: Fifty nine kilometers per gallon.
# --------------------------------------------------
# Prediction: t h e y ' d   s e e n   i t   e a r l i e r .
# Ground Truth: They'd seen it earlier.
# --------------------------------------------------
# Prediction: i t   s h o u l d n ' t   b e   d e s t r o y e d .
# Ground Truth: It shouldn't be destroyed.
# --------------------------------------------------
# Prediction: c h e m i c a l   s e r v i c e s   t o   c o m e .
# Ground Truth: Chemical services to come.
# --------------------------------------------------
# Prediction: w h i c h   i   t h o u g h t   w a s   a   r e a l   i n t e r e s t i n g   q u e s t i o n . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Ground Truth: Which I thought was a real interesting question.
# --------------------------------------------------
# Prediction: w e l l   t h a t ' s   a b o u t   i t   r e a l l y .
# Ground Truth: Well that's about it really.
# --------------------------------------------------
# Prediction: i f   i   d o n ' t   h a v e   a   r e e l   w i t h   a   b u t t o n   o n   i t .
# Ground Truth: If I don't have a reel with a button on it.
# --------------------------------------------------
# Prediction: y o u   g e t   a   l o t   o f   s u n f i s h .
# Ground Truth: You get a lot of sunfish.
# --------------------------------------------------
# Prediction: i   e n j o y   g o i n g   t o   t h e   b e a c h   a n d   t o   b e a c h   a r e a s .
# Ground Truth: I enjoy going to the beach and to beach areas.
# --------------------------------------------------
# Prediction: i   g u e s s   i ' m   p a r t i a l   t o   b i g   t r e e   c o u n t r y .
# Ground Truth: I guess I'm partial to big tree country.
# --------------------------------------------------
# Prediction: t h e y   a r e   b o t h   r e m a r r i e d .
# Ground Truth: They are both remarried.
# --------------------------------------------------
# Prediction: t h e   h i g h   s c h o o l   i   w e n t   t o .
# Ground Truth: The high school I went to.
# --------------------------------------------------
# Prediction: y o u   h a v e   t o   t h i n k   g r a n d c h i l d r e n .
# Ground Truth: You have to think grandchildren.
# --------------------------------------------------
# Prediction: y o u   c o u l d   d o   i t .
# Ground Truth: You could do it.
# --------------------------------------------------
# Prediction: h e   w a s   t r e a t e d   l i k e   a l l   t h e   r e s t   o f   s t u d e n t s .
# Ground Truth: He was treated like all the rest of students.
# --------------------------------------------------
# Prediction: i   d o n ' t   t h i n k   s o   a n y m o r e .
# Ground Truth: I don't think so anymore.
# --------------------------------------------------
# Prediction: t h a t ' s   s t i l l   n o t   e n o u g h   f o r   a   t o t a l .
# Ground Truth: That's still not enough for a total.
# --------------------------------------------------
# Prediction: o n e   t h i n g   l e d   t o   a n o t h e r .
# Ground Truth: One thing led to another.
# --------------------------------------------------
# Prediction: t w o   d i f f e r e n t   p a r t s   o f   t h e   c o u n t r y .
# Ground Truth: Two different parts of the country.
# --------------------------------------------------
# Prediction: i   r e a l l y   d o n ' t   h a v e   a n y   j o b   b e n e f i t s   t o   s p e a k   o f . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Ground Truth: I really don't have any job benefits to speak of.
# --------------------------------------------------
# Prediction: i t   r e a l l y   h e l p s   t h o s e   p e o p l e .
# Ground Truth: It really helps those people.
# --------------------------------------------------
# Prediction: p u t   a   c r a m p   i n   y o u r   v i e w i n g .
# Ground Truth: Put a cramp in your viewing.
# --------------------------------------------------
# Prediction: i t ' s   a   p r e t t y   g o o d   s i z e   c h u r c h .
# Ground Truth: It's a pretty good size church.
# --------------------------------------------------
# Prediction: c a m p i n g   f o r   y o u   i n   a   m o t o r   h o m e .
# Ground Truth: Camping for you in a motor home.
# --------------------------------------------------
# Prediction: i f   y o u ' v e   o n l y   g o t   a   t o k e n   f o r c e   t h e r e .
# Ground Truth: If you've only got a token force there.
# --------------------------------------------------
# Prediction: t h i s   t i m e   o f   t h e   y e a r .
# Ground Truth: This time of the year.
# --------------------------------------------------
# Prediction: i ' d   j u s t   a s   s o o n   a   l o t   f e w e r   p e o p l e   d i d .
# Ground Truth: I'd just as soon a lot fewer people did.
# --------------------------------------------------
# Prediction: t h e y   t h i n k   i t ' s   k i n d   o f   c o o l .
# Ground Truth: They think it's kind of cool.
# --------------------------------------------------
# Prediction: c r i m e   i s   t o o   m u c h .
# Ground Truth: Crime is too much.
# --------------------------------------------------
# Prediction: i   d o n ' t   k n o w   h o w   m y   f a t h e r   d i d   i t .
# Ground Truth: I don't know how my father did it.
# --------------------------------------------------
# Prediction: l i v e d   o n   a   f a r m   f o r   s i x t y   y e a r s .
# Ground Truth: Lived on a farm for sixty years.
# --------------------------------------------------
# Prediction: i   l o o k   a t   h o m e m a k i n g   a s   a   j o b   a l s o .
# Ground Truth: I look at homemaking as a job also.
# --------------------------------------------------
# Prediction: r e a l l y   k i n d   o f   g o n e   t h e   r o u n d s .
# Ground Truth: Really kind of gone the rounds.
# --------------------------------------------------
# Prediction: i   n e v e r   e v e n   k n e w   t h a t .
# Ground Truth: I never even knew that.
# --------------------------------------------------
# Prediction: c l o t h i n g   a n d   g a s .
# Ground Truth: Clothing and gas.
# --------------------------------------------------
# Prediction: t h e   c o m m e r c i a l   d i s t r i c t s .
# Ground Truth: The commercial districts.
# --------------------------------------------------
# Prediction: w h a t ' s   t h e   d i f f e r e n c e   t h e r e ?
# Ground Truth: What's the difference there?
# --------------------------------------------------
# Prediction: i   l i k e   t h a t   k i n d   o f   s t u f f .
# Ground Truth: I like that kind of stuff.
# --------------------------------------------------
# Prediction: w e   m i g h t   a s   w e l l .
# Ground Truth: We might as well.
# --------------------------------------------------
# Prediction: s a v i n g s   a n d   l o a n s .
# Ground Truth: Savings and loans.
# --------------------------------------------------
# Prediction: t h e y   p l a s t e r e d   o v e r   d r y w a l l .
# Ground Truth: They plastered over drywall.
# --------------------------------------------------
# Prediction: i ' l l   s l i c e   w h i t e   g r a p e .
# Ground Truth: I'll slice white grape.
# --------------------------------------------------
# Prediction: t h e   b o m b   d e v e l o p m e n t .
# Ground Truth: The bomb development.
# --------------------------------------------------
# Prediction: o n   t h e   o u t s k i r t s   o f   h o u s t o n .
# Ground Truth: On the outskirts of Houston.
# --------------------------------------------------
# Prediction: i   f o r g e t   h o w   s h e   g o t   i t .
# Ground Truth: I forget how she got it.
# --------------------------------------------------
# Prediction: y o u r   t u i t i o n   r e i m b u r s e m e n t .
# Ground Truth: Your tuition reimbursement.
# --------------------------------------------------
# Prediction: g e t t i n g   p l e d g e   s h e e t s   f o r   t h e   b o y   s c o u t s .
# Ground Truth: Getting pledge sheets for the Boy Scouts.
# --------------------------------------------------
# Prediction: i f   y o u   h a v e   a n y   d o u b t s   w h a t s o e v e r .
# Ground Truth: If you have any doubts whatsoever.
# --------------------------------------------------
# Prediction: m y s t e r y   m o v i e s .
# Ground Truth: Mystery movies.
# --------------------------------------------------
# Prediction: i   c a n ' t   r e m e m b e r   w h e r e .
# Ground Truth: I can't remember where.
# --------------------------------------------------

# %%
# Save the model
model.save('lstm_model.h5')
print("Model saved as lstm_model.h5")
# Save the tokenizer
import json
with open('tokenizer.json', 'w') as f:
    json.dump(tokenizer.to_json(), f)
print("Tokenizer saved as tokenizer.json")
# Out:
# Model saved as lstm_model.h5
# Tokenizer saved as tokenizer.json

# %%
import numpy as np
import os
import json
import scipy.io
import tensorflow as tf
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.text import tokenizer_from_json
from nltk.translate.bleu_score import corpus_bleu

# --- Load model and tokenizer ---
model = load_model('lstm_model.h5')
print("✅ Model loaded.")

with open('tokenizer.json') as f:
    tokenizer_json = json.load(f)
tokenizer = tokenizer_from_json(tokenizer_json)
print("✅ Tokenizer loaded.")

# --- Define test data loading ---
area6v_indices = np.arange(0, 128)

def load_test_data(test_folder):
    X_test = []
    y_test = []

    for filename in os.listdir(test_folder):
        if filename.endswith('.mat'):
            file_path = os.path.join(test_folder, filename)
            mat = scipy.io.loadmat(file_path)

            spikePow = mat['spikePow'].squeeze()
            tx1 = mat['tx1'].squeeze()
            blockIdx = mat['blockIdx'].squeeze()
            sentenceText = mat['sentenceText']

            num_trials = len(spikePow)

            for i in range(num_trials):
                spike_trial = spikePow[i][:, area6v_indices]
                tx1_trial = tx1[i][:, area6v_indices]
                trial_features = np.concatenate([spike_trial, tx1_trial], axis=1)

                block_id = blockIdx[i]
                block_mask = (blockIdx == block_id)
                block_trials = [np.concatenate([spikePow[j][:, area6v_indices], tx1[j][:, area6v_indices]], axis=1)
                                for j in range(num_trials) if block_mask[j]]
                block_data = np.vstack(block_trials)
                mean = block_data.mean(axis=0)
                std = block_data.std(axis=0) + 1e-8

                trial_features = (trial_features - mean) / std

                sentence_entry = sentenceText[i]
                if isinstance(sentence_entry, np.ndarray):
                    sentence = ''.join(chr(int(c)) for c in sentence_entry.flatten() if c != 0)
                elif isinstance(sentence_entry, str):
                    sentence = sentence_entry
                else:
                    sentence = str(sentence_entry)

                X_test.append(trial_features)
                y_test.append(sentence)

    return X_test, y_test

# --- Load and prepare test data ---
X_test, y_test = load_test_data('dataset/test')
print(f"✅ Loaded {len(X_test)} test samples.")
# Out:
# ✅ Model loaded.
# ✅ Tokenizer loaded.
# ✅ Loaded 880 test samples.

# %%
# --- Pad inputs ---
max_timesteps = 906   # ✅ MATCHES model input

X_test_padded = np.array([
    np.pad(x[:max_timesteps], ((0, max(0, max_timesteps - x.shape[0])), (0, 0)), mode='constant')
    for x in X_test
])

# --- Prepare outputs ---
y_test_sequences = tokenizer.texts_to_sequences(y_test)
max_label_len = 88  # Replace with your training max_label_len
y_test_padded = pad_sequences(y_test_sequences, maxlen=max_label_len, padding='post')

# --- Make predictions ---
predictions = model.predict([X_test_padded, y_test_padded])

# Decode the predictions
predicted_token_ids = np.argmax(predictions, axis=-1)
decoded_sentences = tokenizer.sequences_to_texts(predicted_token_ids)

# --- Evaluate ---
# Remove padding tokens from both predictions and ground truth
def remove_padding(sentence, pad_token="<pad>"):
    return [word for word in sentence if word != pad_token]

# Remove padding from decoded sentences and ground truth
decoded_sentences_filtered = [remove_padding(pred.split()) for pred in decoded_sentences]
y_test_filtered = [remove_padding(true.split()) for true in y_test]

# Calculate BLEU score on filtered sentences
bleu_score = corpus_bleu([[true] for true in y_test_filtered], decoded_sentences_filtered)

# Print predictions with ground truth
for i, (pred, true) in enumerate(zip(decoded_sentences, y_test), 1):
    print(f"[{i}] Prediction   : {pred}")
    print(f"    Ground Truth : {true}")
    print("-" * 60)

# Output BLEU score
print(f"\n🎯 Final Corpus BLEU Score: {bleu_score:.4f}")
# Out:
# 28/28 [==============================] - 10s 303ms/step
# [1] Prediction   : t h e o c r a c y   r e c o n s i d e r e d .
#     Ground Truth : Theocracy reconsidered.
# ------------------------------------------------------------
# [2] Prediction   : r i c h   p u r c h a s e d   s e v e r a l   s i g n e d   l i t h o g r a p h s .
#     Ground Truth : Rich purchased several signed lithographs.
# ------------------------------------------------------------
# [3] Prediction   : s o   r u l e s   w e   m a d e ,   i n   u n a b a s h e d   c o l l u s i o n .
#     Ground Truth : So rules we made, in unabashed collusion.
# ------------------------------------------------------------
# [4] Prediction   : l o r i ' s   c o s t u m e   n e e d e d   b l a c k   g l o v e s   t o   b e   c o m p l e t e l y   e l e g a n t .
#     Ground Truth : Lori's costume needed black gloves to be completely elegant.
# ------------------------------------------------------------
# [5] Prediction   : t h e   t o o t h   f a i r y   f o r g o t   t o   c o m e   w h e n   r o g e r ' s   t o o t h   f e l l   o u t .
#     Ground Truth : The tooth fairy forgot to come when Roger's tooth fell out.
# ------------------------------------------------------------
# [6] Prediction   : t h a t   s t i n g i n g   v a p o r   w a s   c a u s e d   b y   c h l o r i d e   v a p o r i z a t i o n .
#     Ground Truth : That stinging vapor was caused by chloride vaporization.
# ------------------------------------------------------------
# [7] Prediction   : b e f o r e   t h u r s d a y ' s   e x a m ,   r e v i e w   e v e r y   f o r m u l a .
#     Ground Truth : Before Thursday's exam, review every formula.
# ------------------------------------------------------------
# [8] Prediction   : w i l d f i r e   n e a r   s u n s h i n e   f o r c e s   p a r k   c l o s u r e s .
#     Ground Truth : Wildfire near Sunshine forces park closures.
# ------------------------------------------------------------
# [9] Prediction   : t h e   w o r d   m e a n s   i t   w o n ' t   b o i l   a w a y   e a s i l y ,   n o t h i n g   e l s e .
#     Ground Truth : The word means it won't boil away easily, nothing else.
# ------------------------------------------------------------
# [10] Prediction   : w o u l d   a   b l u e   f e a t h e r   i n   a   m a n ' s   h a t   m a k e   h i m   h a p p y   a l l   d a y ?
#     Ground Truth : Would a blue feather in a man's hat make him happy all day?
# ------------------------------------------------------------
# [11] Prediction   : h e   t a l k e d   a b o u t   u n a u t h e n t i c   s t o r y l i n e s   t o o .
#     Ground Truth : He talked about unauthentic storylines too.
# ------------------------------------------------------------
# [12] Prediction   : m o s t   y o u n g   r i s e   e a r l y   e v e r y   m o r n i n g .
#     Ground Truth : Most young rise early every morning.
# ------------------------------------------------------------
# [13] Prediction   : w i t h   t h i s   n o   l o y a l   c i t i z e n   c a n   q u a r r e l .
#     Ground Truth : With this no loyal citizen can quarrel.
# ------------------------------------------------------------
# [14] Prediction   : p r i m i t i v e   t r i b e s   h a v e   a n   u p b e a t   a t t i t u d e .
#     Ground Truth : Primitive tribes have an upbeat attitude.
# ------------------------------------------------------------
# [15] Prediction   : a n d   i t   w a s   n o t   a   j u d g e ,   b u t   a   j u s t i c e   o f   t h e   p e a c e   w h o   m a d e   t h e   d e c i s i o n .
#     Ground Truth : And it was not a judge, but a justice of the peace who made the decision.
# ------------------------------------------------------------
# [16] Prediction   : w e   s e e m e d   t o   b e   w i t n e s s i n g   t h e   p o p u l a t i o n   e x p l o s i o n   r i g h t   i n   o u r   o w n   b a c k y a r d s .
#     Ground Truth : We seemed to be witnessing the population explosion right in our own backyards.
# ------------------------------------------------------------
# [17] Prediction   : s o m e t i m e s ,   d e s p e r a t e   m e a s u r e s   c a n   a l s o   t u r n   i n t o   s o l i d   m o v e s   f o r   t h e   f u t u r e .
#     Ground Truth : Sometimes, desperate measures can also turn into solid moves for the future.
# ------------------------------------------------------------
# [18] Prediction   : t h o s e   a n s w e r s   w i l l   b e   s t r a i g h t f o r w a r d   i f   y o u   t h i n k   t h e m   t h r o u g h   c a r e f u l l y   f i r s t . . . . . . . . .
#     Ground Truth : Those answers will be straightforward if you think them through carefully first.
# ------------------------------------------------------------
# [19] Prediction   : s h e   g e t s   d r e s s e d   f a s t e r   a n d   s p e n d s   l e s s   e n e r g y   m a k i n g   c l o t h i n g   d e c i s i o n s .
#     Ground Truth : She gets dressed faster and spends less energy making clothing decisions.
# ------------------------------------------------------------
# [20] Prediction   : a c a d e m i c   a p t i t u d e   g u a r a n t e e s   y o u r   d i p l o m a .
#     Ground Truth : Academic aptitude guarantees your diploma.
# ------------------------------------------------------------
# [21] Prediction   : t o   s o m e   e x t e n t   p r e d i s p o s i t i o n s   a r e   s h a p e d   b y   e x p o s u r e   t o   g r o u p   e n v i r o n m e n t s .
#     Ground Truth : To some extent predispositions are shaped by exposure to group environments.
# ------------------------------------------------------------
# [22] Prediction   : a n   a d u l t   m a l e   b a b o o n ' s   t e e t h   a r e   n o t   s u i t a b l e   f o r   e a t i n g   s h e l l f i s h .
#     Ground Truth : An adult male baboon's teeth are not suitable for eating shellfish.
# ------------------------------------------------------------
# [23] Prediction   : i n   t h i s   c o n t e x t ,   i t   w o u l d   d o   w e l l   f o r   u s   t o   b e a r   i n   m i n d   t h e   v i s i o n   o f   p e a c e .
#     Ground Truth : In this context, it would do well for us to bear in mind the vision of peace.
# ------------------------------------------------------------
# [24] Prediction   : y o u ' r e   b o i l i n g   m i l k ,   a i n ' t   y o u ?
#     Ground Truth : You're boiling milk, ain't you?
# ------------------------------------------------------------
# [25] Prediction   : r i c h   l o o k e d   f o r   s p o t t e d   h y e n a s   a n d   j a g u a r s   o n   t h e   s a f a r i .
#     Ground Truth : Rich looked for spotted hyenas and jaguars on the safari.
# ------------------------------------------------------------
# [26] Prediction   : t r a f f i c   f r e q u e n t l y   h a s   f a i l e d   t o   m e a s u r e   u p   t o   e n g i n e e r s '   r o s y   e s t i m a t e s .
#     Ground Truth : Traffic frequently has failed to measure up to engineers' rosy estimates.
# ------------------------------------------------------------
# [27] Prediction   : r a l p h   p r e p a r e d   r e d   s n a p p e r   w i t h   f r e s h   l e m o n   s a u c e   f o r   d i n n e r .
#     Ground Truth : Ralph prepared red snapper with fresh lemon sauce for dinner.
# ------------------------------------------------------------
# [28] Prediction   : d i d   y o u   b u y   a n y   c o r d u r o y   o v e r a l l s ?
#     Ground Truth : Did you buy any corduroy overalls?
# ------------------------------------------------------------
# [29] Prediction   : c l e a r   p r o n u n c i a t i o n   i s   a p p r e c i a t e d .
#     Ground Truth : Clear pronunciation is appreciated.
# ------------------------------------------------------------
# [30] Prediction   : p l e a s e   s h o r t e n   t h i s   s k i r t   f o r   j o y c e .
#     Ground Truth : Please shorten this skirt for Joyce.
# ------------------------------------------------------------
# [31] Prediction   : w h o   a u t h o r i z e d   t h e   u n l i m i t e d   e x p e n s e   a c c o u n t ?
#     Ground Truth : Who authorized the unlimited expense account?
# ------------------------------------------------------------
# [32] Prediction   : t h e   f a m i l y   r e q u e s t s   t h a t   f l o w e r s   b e   o m i t t e d .
#     Ground Truth : The family requests that flowers be omitted.
# ------------------------------------------------------------
# [33] Prediction   : t h e   m u s e u m   h i r e s   m u s i c i a n s   e v e r y   e v e n i n g .
#     Ground Truth : The museum hires musicians every evening.
# ------------------------------------------------------------
# [34] Prediction   : w e ' l l   s e r v e   r h u b a r b   p i e   a f t e r   r a c h e l ' s   t a l k .
#     Ground Truth : We'll serve rhubarb pie after Rachel's talk.
# ------------------------------------------------------------
# [35] Prediction   : t h e y   e n j o y   i t   w h e n   i   a u d i t i o n .
#     Ground Truth : They enjoy it when I audition.
# ------------------------------------------------------------
# [36] Prediction   : t h e   a v o c a d o   s h o u l d   h a v e   a   g i v e   t o   i t ,   a s   y o u   h o l d   i t ,   w h e n   i t   i s   r i p e .
#     Ground Truth : The avocado should have a give to it, as you hold it, when it is ripe.
# ------------------------------------------------------------
# [37] Prediction   : e n e r g y   s u p p l i e r s   u s u a l l y   d e a l   w i t h   t h i s   b y   c o n d u c t i n g   r e g u l a r   i n s p e c t i o n s   a n d   t r i m m i n g . .
#     Ground Truth : Energy suppliers usually deal with this by conducting regular inspections and trimming.
# ------------------------------------------------------------
# [38] Prediction   : t h e   s a w   i s   b r o k e n ,   s o   c h o p   t h e   w o o d   i n s t e a d .
#     Ground Truth : The saw is broken, so chop the wood instead.
# ------------------------------------------------------------
# [39] Prediction   : t h e   c l e a n e d   v e r s i o n   i s   g i v e n   b e l o w .
#     Ground Truth : The cleaned version is given below.
# ------------------------------------------------------------
# [40] Prediction   : t h e y   s e e m   d a r n e d   p r o u d   o f   i t .
#     Ground Truth : They seem darned proud of it.
# ------------------------------------------------------------
# [41] Prediction   : a   s h a r p   t r e m o r   w a s   f o l l o w e d   b y   a   j e r k y   r o l l .
#     Ground Truth : A sharp tremor was followed by a jerky roll.
# ------------------------------------------------------------
# [42] Prediction   : b o y ,   y o u   a i n ' t   f o o l i n g   n o b o d y   b u t   y o u r s e l f .
#     Ground Truth : Boy, you ain't fooling nobody but yourself.
# ------------------------------------------------------------
# [43] Prediction   : t e a c h i n g   g u i d e s   a r e   i n c l u d e d   w i t h   e a c h   r e c o r d . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
#     Ground Truth : Teaching guides are included with each record.
# ------------------------------------------------------------
# [44] Prediction   : t h e   m a n ' s   e y e l i d s   f l u t t e r e d .
#     Ground Truth : The man's eyelids fluttered.
# ------------------------------------------------------------
# [45] Prediction   : t h i s   k i d ' s   f r o z e   b a d .
#     Ground Truth : This kid's froze bad.
# ------------------------------------------------------------
# [46] Prediction   : s h e   r a d i a t e d   w a r m t h   a n d   g o o d   f e l l o w s h i p .
#     Ground Truth : She radiated warmth and good fellowship.
# ------------------------------------------------------------
# [47] Prediction   : d o   y o u   k n o w   w h e r e   i t   m i g h t   h a v e   g o n e ?
#     Ground Truth : Do you know where it might have gone?
# ------------------------------------------------------------
# [48] Prediction   : i n   t h e   p i t y   f o r   t h e m   h i s   l o n e l i n e s s   w a s   g o n e .
#     Ground Truth : In the pity for them his loneliness was gone.
# ------------------------------------------------------------
# [49] Prediction   : j o i n   u s   o n   t w i t t e r   a n d   f a c e b o o k
#     Ground Truth : Join us on Twitter and Facebook
# ------------------------------------------------------------
# [50] Prediction   : h e   s a i d   t h e y ' l l   b e   w o r k i n g   t o w a r d   a   d e c i s i o n .
#     Ground Truth : He said they'll be working toward a decision.
# ------------------------------------------------------------
# [51] Prediction   : s h a v i n g   c r e a m   i s   a   p o p u l a r   i t e m   o n   h a l l o w e e n .
#     Ground Truth : Shaving cream is a popular item on Halloween.
# ------------------------------------------------------------
# [52] Prediction   : t h e n   s i m m e r   f i f t e e n   m i n u t e s   l o n g e r .
#     Ground Truth : Then simmer fifteen minutes longer.
# ------------------------------------------------------------
# [53] Prediction   : a   t h i r d   s h o t   d o u s e d   t h e   l i g h t .
#     Ground Truth : A third shot doused the light.
# ------------------------------------------------------------
# [54] Prediction   : t h e   g u t t u r a l   l a n g u a g e   f r o m   t h e   g h e t t o   s t o p p e d . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
#     Ground Truth : The guttural language from the ghetto stopped.
# ------------------------------------------------------------
# [55] Prediction   : l i k e   a s   i f   i t   w e r e   b u i l t   o f   b o o k s .
#     Ground Truth : Like as if it were built of books.
# ------------------------------------------------------------
# [56] Prediction   : t h e n   h e   - -   t h e n   w h a t ?
#     Ground Truth : Then he -- then what?
# ------------------------------------------------------------
# [57] Prediction   : i   a m   a n   a r t i s t ,   l o s t   i n   m y   o w n   v i s i o n .
#     Ground Truth : I am an artist, lost in my own vision.
# ------------------------------------------------------------
# [58] Prediction   : b l o c k a d e   i s   o n e   a n s w e r   o f f e r e d   b y   e x p e r t s .
#     Ground Truth : Blockade is one answer offered by experts.
# ------------------------------------------------------------
# [59] Prediction   : t h o s e   m u s i c i a n s   h a r m o n i z e   m a r v e l o u s l y .
#     Ground Truth : Those musicians harmonize marvelously.
# ------------------------------------------------------------
# [60] Prediction   : i t   a l l   d i d   l o o k   v e r y   e f f i c i e n t   a n d   s h i p s h a p e .
#     Ground Truth : It all did look very efficient and shipshape.
# ------------------------------------------------------------
# [61] Prediction   : y e t   w e   n o   l o n g e r   f e e l   u n e a s y .
#     Ground Truth : Yet we no longer feel uneasy.
# ------------------------------------------------------------
# [62] Prediction   : i n f l a m m a t o r y   c e l l s   w e r e   s t r i k i n g l y   a b s e n t .
#     Ground Truth : Inflammatory cells were strikingly absent.
# ------------------------------------------------------------
# [63] Prediction   : i t   c a n   p r o j e c t   l o n g - r a n g e   g o a l s   f o r   i t s e l f .
#     Ground Truth : It can project long-range goals for itself.
# ------------------------------------------------------------
# [64] Prediction   : i n t e l l i g e n c e   j a b b e d   a t   h i m   a c c u s i n g l y .
#     Ground Truth : Intelligence jabbed at him accusingly.
# ------------------------------------------------------------
# [65] Prediction   : d o   y o u   h e a r   t h e   s l e i g h   b e l l s   r i n g i n g ?
#     Ground Truth : Do you hear the sleigh bells ringing?
# ------------------------------------------------------------
# [66] Prediction   : t h e r e   w a s   m u c h   e m b r a c i n g ,   m u c h   e x c l a i m i n g .
#     Ground Truth : There was much embracing, much exclaiming.
# ------------------------------------------------------------
# [67] Prediction   : b e l o w   i s   a   s p e c i f i c   g u i d e ,   k e y e d   t o   t h e   c a l e n d a r . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
#     Ground Truth : Below is a specific guide, keyed to the calendar.
# ------------------------------------------------------------
# [68] Prediction   : f i n a l l y   h e   a s k e d ,   d o   y o u   o b j e c t   t o   p e t t i n g ?
#     Ground Truth : Finally he asked, do you object to petting?
# ------------------------------------------------------------
# [69] Prediction   : w e ' l l   p a y   y o u   b a c k   i f   y o u ' l l   l e t   u s .
#     Ground Truth : We'll pay you back if you'll let us.
# ------------------------------------------------------------
# [70] Prediction   : t h e y   c l o s e   s o m e t i m e   a f t e r   e i g h t .
#     Ground Truth : They close sometime after eight.
# ------------------------------------------------------------
# [71] Prediction   : t h e n   w e   w e r e   o f f   a g a i n .
#     Ground Truth : Then we were off again.
# ------------------------------------------------------------
# [72] Prediction   : h i s   w i f e   d i d n ' t   g i v e   a   s i g n   s h e ' d   h e a r d .
#     Ground Truth : His wife didn't give a sign she'd heard.
# ------------------------------------------------------------
# [73] Prediction   : f o r   a   m a n   o f   h i s   m a s s   h e   w a s   c u r i o u s l y   s h o r t .
#     Ground Truth : For a man of his mass he was curiously short.
# ------------------------------------------------------------
# [74] Prediction   : p a m   g i v e s   d r i v i n g   l e s s o n s   o n   t h u r s d a y s .
#     Ground Truth : Pam gives driving lessons on Thursdays.
# ------------------------------------------------------------
# [75] Prediction   : r e a d   t h e   d e c i s i o n   b e l o w .
#     Ground Truth : Read the decision below.
# ------------------------------------------------------------
# [76] Prediction   : r e c e i v i n g   n o   a n s w e r ,   t h e y   s e t   t h e   f i r e .
#     Ground Truth : Receiving no answer, they set the fire.
# ------------------------------------------------------------
# [77] Prediction   : w h e r e   i s   y o u r   u s u a l   u p b e a t   p e r s o n a l i t y ?
#     Ground Truth : Where is your usual upbeat personality?
# ------------------------------------------------------------
# [78] Prediction   : n i c e   c o u n t r y   t o   m e e t   a   l i o n   i n   f a c e   t o   f a c e .
#     Ground Truth : Nice country to meet a lion in face to face.
# ------------------------------------------------------------
# [79] Prediction   : w i t h   a   w h i r l i n g   j u m p ,   i t   c o u l d   g e t   i n t o   g e a r .
#     Ground Truth : With a whirling jump, it could get into gear.
# ------------------------------------------------------------
# [80] Prediction   : m a r k s m a n s h i p   e x a m p l e .
#     Ground Truth : Marksmanship example.
# ------------------------------------------------------------
# [81] Prediction   : i t ' s   r e a l l y   h a r d   t o   f i n d   s o m e t h i n g   t h a t   w o r k s .
#     Ground Truth : It's really hard to find something that works.
# ------------------------------------------------------------
# [82] Prediction   : a n d   i   l o v e d   t h s   s h i n i n g .
#     Ground Truth : And I loved ths shining.
# ------------------------------------------------------------
# [83] Prediction   : i   d o   h a v e   a   f r i e n d   t h a t   r a n .
#     Ground Truth : I do have a friend that ran.
# ------------------------------------------------------------
# [84] Prediction   : j u s t   w a y   i n   t h e   b a c k .
#     Ground Truth : Just way in the back.
# ------------------------------------------------------------
# [85] Prediction   : a c t u a l l y ,   i t   m a k e s   s e n s e   t o   a   c e r t a i n   e x t e n t .
#     Ground Truth : Actually, it makes sense to a certain extent.
# ------------------------------------------------------------
# [86] Prediction   : a s s u r e   t h e   g o v e r n m e n t   t h a t   h e   w a s   e m p l o y e d .
#     Ground Truth : Assure the government that he was employed.
# ------------------------------------------------------------
# [87] Prediction   : t h e y   f e e l   g o o d   a b o u t   w h a t   t h e y ' r e   d o i n g .
#     Ground Truth : They feel good about what they're doing.
# ------------------------------------------------------------
# [88] Prediction   : b e s i d e s ,   i t s   a n   i n v a s i o n   o f   p e r s o n a l   p r i v a c y .
#     Ground Truth : Besides, its an invasion of personal privacy.
# ------------------------------------------------------------
# [89] Prediction   : s o   y o u   t r a v e l   a   l o t ?
#     Ground Truth : So you travel a lot?
# ------------------------------------------------------------
# [90] Prediction   : s o   w e ' r e   g o i n g   t o   w a i t .
#     Ground Truth : So we're going to wait.
# ------------------------------------------------------------
# [91] Prediction   : a n y   k i n d   o f   a   g o o d   e n v i r o n m e n t   t o   l i v e   i n .
#     Ground Truth : Any kind of a good environment to live in.
# ------------------------------------------------------------
# [92] Prediction   : t h e   b e s t   o f   a n d r o i d .
#     Ground Truth : The best of Android.
# ------------------------------------------------------------
# [93] Prediction   : i   d o n ' t   k n o w   w h a t   y o u   t h i n k   a b o u t   t h e   p o i n t .
#     Ground Truth : I don't know what you think about the point.
# ------------------------------------------------------------
# [94] Prediction   : i   b e l i e v e   i t   c o s t s   a b o u t   t e n   d o l l a r s .
#     Ground Truth : I believe it costs about ten dollars.
# ------------------------------------------------------------
# [95] Prediction   : w h a t   i n   t h e   w o r l d   d r u g s   a r e   y o u   o n   t o ?
#     Ground Truth : What in the world drugs are you on to?
# ------------------------------------------------------------
# [96] Prediction   : a n d r o i d   t v   b o x .
#     Ground Truth : Android TV box.
# ------------------------------------------------------------
# [97] Prediction   : a   c o u p l e   o f   t i m e s .
#     Ground Truth : A couple of times.
# ------------------------------------------------------------
# [98] Prediction   : i   h a d   t h e   b r a k e s   d o n e   o n   i t .
#     Ground Truth : I had the brakes done on it.
# ------------------------------------------------------------
# [99] Prediction   : w h i c h   i   u s e   a s   a   r e f e r e n c e   a n d   h a s   b e e n   r e a l   h a n d y . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
#     Ground Truth : Which I use as a reference and has been real handy.
# ------------------------------------------------------------
# [100] Prediction   : i   k n o w   w h e n   i   w a s   w o r k i n g .
#     Ground Truth : I know when I was working.
# ------------------------------------------------------------
# [101] Prediction   : i t ' s   a   p a c k a g e   d e a l .
#     Ground Truth : It's a package deal.
# ------------------------------------------------------------
# [102] Prediction   : i   h a v e   s e e n   i t .
#     Ground Truth : I have seen it.
# ------------------------------------------------------------
# [103] Prediction   : t h e   m e a s u r e s   a l r e a d y   p a s s e d   a   s e n a t e   c o m m i t t e e .
#     Ground Truth : The measures already passed a Senate committee.
# ------------------------------------------------------------
# [104] Prediction   : t h e y   t o l d   m e   t h a t   t h i s   w a s   a   t o p i c .
#     Ground Truth : They told me that this was a topic.
# ------------------------------------------------------------
# [105] Prediction   : i n   t h e   r e d   s q u a r e   o r   w h e r e v e r   s a i d .
#     Ground Truth : In the Red Square or wherever said.
# ------------------------------------------------------------
# [106] Prediction   : t h e y   d i d   a   l o t   o f   p l a y   w o r k   a n d   s t u f f .
#     Ground Truth : They did a lot of play work and stuff.
# ------------------------------------------------------------
# [107] Prediction   : y o u   c a n   g a i n   t o o   m u c h   w e i g h t .
#     Ground Truth : You can gain too much weight.
# ------------------------------------------------------------
# [108] Prediction   : r e c e n t   l e g i s l a t i o n .
#     Ground Truth : Recent legislation.
# ------------------------------------------------------------
# [109] Prediction   : i ' m   a   c a r   b u f f   t o o .
#     Ground Truth : I'm a car buff too.
# ------------------------------------------------------------
# [110] Prediction   : j o y   s p r i n g s   f r o m   a   g r a t e f u l   h e a r t .
#     Ground Truth : Joy springs from a grateful heart.
# ------------------------------------------------------------
# [111] Prediction   : c h a r   o n i o n   o v e r   g r i l l ,   n e v e r   a l l o w   o i l   t o   s m o k e .
#     Ground Truth : Char onion over grill, never allow oil to smoke.
# ------------------------------------------------------------
# [112] Prediction   : n o i s e   c a u s e s   a i r   p o l l u t i o n .
#     Ground Truth : Noise causes air pollution.
# ------------------------------------------------------------
# [113] Prediction   : a n d   t h e n   y o u   s p r i n k l e   t h e   c h e e s e   o n   t o p   o f   t h a t .
#     Ground Truth : And then you sprinkle the cheese on top of that.
# ------------------------------------------------------------
# [114] Prediction   : j u s t   s a y i n g   t h a t   c l e a r   v i s i o n   i s   a   n e c e s s i t y .
#     Ground Truth : Just saying that clear vision is a necessity.
# ------------------------------------------------------------
# [115] Prediction   : f a c t o r s   t h a t   a f f e c t   e a r n i n g s   o f   a n   e m p l o y e e .
#     Ground Truth : Factors that affect earnings of an employee.
# ------------------------------------------------------------
# [116] Prediction   : i f   y o u   d r i n k   a   l o t   o f   c a f f e i n e   y o u ' l l   s t a y   a w a k e .
#     Ground Truth : If you drink a lot of caffeine you'll stay awake.
# ------------------------------------------------------------
# [117] Prediction   : t h a t ' s   a   n i c e   c a r .
#     Ground Truth : That's a nice car.
# ------------------------------------------------------------
# [118] Prediction   : v i s i o n a r y   l e a d e r s .
#     Ground Truth : Visionary leaders.
# ------------------------------------------------------------
# [119] Prediction   : t h e   o n l y   o t h e r   p l a c e   i ' v e   e v e r   v a c a t i o n e d .
#     Ground Truth : The only other place I've ever vacationed.
# ------------------------------------------------------------
# [120] Prediction   : i   j u s t   k i n d   o f   w e n t   t h r o u g h .
#     Ground Truth : I just kind of went through.
# ------------------------------------------------------------
# [121] Prediction   : t h i s   i s   u n i f y i n g   v o i c e   w e   n e e d .
#     Ground Truth : This is unifying voice we need.
# ------------------------------------------------------------
# [122] Prediction   : d o   y o u   h a v e   y o u r   b a g ?
#     Ground Truth : Do you have your bag?
# ------------------------------------------------------------
# [123] Prediction   : s o   y o u   k n o w   i t   k e e p s   u s   p r e t t y   b u s y .
#     Ground Truth : So you know it keeps us pretty busy.
# ------------------------------------------------------------
# [124] Prediction   : t h a t ' s   a   s c i e n c e   i n   i t s e l f .
#     Ground Truth : That's a science in itself.
# ------------------------------------------------------------
# [125] Prediction   : s o   w h e n   y o u   g e t   i n   t i g h t   s i t u a t i o n s ?
#     Ground Truth : So when you get in tight situations?
# ------------------------------------------------------------
# [126] Prediction   : i   c a n   r e l a t e   t o   t h a t .
#     Ground Truth : I can relate to that.
# ------------------------------------------------------------
# [127] Prediction   : i t ' s   a l l   r e a d y   q u i t   p l a y i n g .
#     Ground Truth : It's all ready quit playing.
# ------------------------------------------------------------
# [128] Prediction   : i f   t h e y ' r e   a r o u n d   a n y m o r e .
#     Ground Truth : If they're around anymore.
# ------------------------------------------------------------
# [129] Prediction   : i   a m   n o t   e v e n   a w a r e   t h a t   i   c o u l d   h a v e   s e e n   i t .
#     Ground Truth : I am not even aware that I could have seen it.
# ------------------------------------------------------------
# [130] Prediction   : t h e   r a n k s   o f   a s i a n   r i d e r s   a r e   s w e l l i n g   t o o .
#     Ground Truth : The ranks of Asian riders are swelling too.
# ------------------------------------------------------------
# [131] Prediction   : e i n s t e i n   e q u a t i o n .
#     Ground Truth : Einstein equation.
# ------------------------------------------------------------
# [132] Prediction   : m o s t   p o i n t s   a t   t h e   e n d   w i n s !
#     Ground Truth : Most points at the end wins!
# ------------------------------------------------------------
# [133] Prediction   : i   t h i n k   i t ' s   o n e   h u n d r e d   a n d   e i g h t y   m i l e s .
#     Ground Truth : I think it's one hundred and eighty miles.
# ------------------------------------------------------------
# [134] Prediction   : w e   d o n ' t   u s u a l l y   t a k e   t h e   k i d s   w h e n   w e   g o   t h e r e .
#     Ground Truth : We don't usually take the kids when we go there.
# ------------------------------------------------------------
# [135] Prediction   : o n e   o f   t h o s e   g e n e r a t i o n   n o v e l s .
#     Ground Truth : One of those generation novels.
# ------------------------------------------------------------
# [136] Prediction   : t h e y   ' l l   n e v e r   g e t   c a u g h t .
#     Ground Truth : They 'll never get caught.
# ------------------------------------------------------------
# [137] Prediction   : i   d o n ' t   b u y   t h e   n e w s p a p e r .
#     Ground Truth : I don't buy the newspaper.
# ------------------------------------------------------------
# [138] Prediction   : b r i n g i n g   s o m e t h i n g   f o r   a   p o t l u c k   p i c n i c .
#     Ground Truth : Bringing something for a potluck picnic.
# ------------------------------------------------------------
# [139] Prediction   : i   ' l l   t a k e   i t   o u t .
#     Ground Truth : I 'll take it out.
# ------------------------------------------------------------
# [140] Prediction   : i m p r o v e d   e v a s i o n   d o e s   n o t   w o r k .
#     Ground Truth : Improved evasion does not work.
# ------------------------------------------------------------
# [141] Prediction   : c a s u a l t i e s   w e r e   r e p o r t e d .
#     Ground Truth : Casualties were reported.
# ------------------------------------------------------------
# [142] Prediction   : y o u   j u s t   l i k e   t o   s i t   d o w n   a n d   w a t c h   i t .
#     Ground Truth : You just like to sit down and watch it.
# ------------------------------------------------------------
# ...
#     Ground Truth : Which I thought was a real interesting question.
# ------------------------------------------------------------
# [836] Prediction   : w e l l   t h a t ' s   a b o u t   i t   r e a l l y .
#     Ground Truth : Well that's about it really.
# ------------------------------------------------------------
# [837] Prediction   : i f   i   d o n ' t   h a v e   a   r e e l   w i t h   a   b u t t o n   o n   i t .
#     Ground Truth : If I don't have a reel with a button on it.
# ------------------------------------------------------------
# [838] Prediction   : y o u   g e t   a   l o t   o f   s u n f i s h .
#     Ground Truth : You get a lot of sunfish.
# ------------------------------------------------------------
# [839] Prediction   : i   e n j o y   g o i n g   t o   t h e   b e a c h   a n d   t o   b e a c h   a r e a s .
#     Ground Truth : I enjoy going to the beach and to beach areas.
# ------------------------------------------------------------
# [840] Prediction   : i   g u e s s   i ' m   p a r t i a l   t o   b i g   t r e e   c o u n t r y .
#     Ground Truth : I guess I'm partial to big tree country.
# ------------------------------------------------------------
# [841] Prediction   : t h e y   a r e   b o t h   r e m a r r i e d .
#     Ground Truth : They are both remarried.
# ------------------------------------------------------------
# [842] Prediction   : t h e   h i g h   s c h o o l   i   w e n t   t o .
#     Ground Truth : The high school I went to.
# ------------------------------------------------------------
# [843] Prediction   : y o u   h a v e   t o   t h i n k   g r a n d c h i l d r e n .
#     Ground Truth : You have to think grandchildren.
# ------------------------------------------------------------
# [844] Prediction   : y o u   c o u l d   d o   i t .
#     Ground Truth : You could do it.
# ------------------------------------------------------------
# [845] Prediction   : h e   w a s   t r e a t e d   l i k e   a l l   t h e   r e s t   o f   s t u d e n t s .
#     Ground Truth : He was treated like all the rest of students.
# ------------------------------------------------------------
# [846] Prediction   : i   d o n ' t   t h i n k   s o   a n y m o r e .
#     Ground Truth : I don't think so anymore.
# ------------------------------------------------------------
# [847] Prediction   : t h a t ' s   s t i l l   n o t   e n o u g h   f o r   a   t o t a l .
#     Ground Truth : That's still not enough for a total.
# ------------------------------------------------------------
# [848] Prediction   : o n e   t h i n g   l e d   t o   a n o t h e r .
#     Ground Truth : One thing led to another.
# ------------------------------------------------------------
# [849] Prediction   : t w o   d i f f e r e n t   p a r t s   o f   t h e   c o u n t r y .
#     Ground Truth : Two different parts of the country.
# ------------------------------------------------------------
# [850] Prediction   : i   r e a l l y   d o n ' t   h a v e   a n y   j o b   b e n e f i t s   t o   s p e a k   o f . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
#     Ground Truth : I really don't have any job benefits to speak of.
# ------------------------------------------------------------
# [851] Prediction   : i t   r e a l l y   h e l p s   t h o s e   p e o p l e .
#     Ground Truth : It really helps those people.
# ------------------------------------------------------------
# [852] Prediction   : p u t   a   c r a m p   i n   y o u r   v i e w i n g .
#     Ground Truth : Put a cramp in your viewing.
# ------------------------------------------------------------
# [853] Prediction   : i t ' s   a   p r e t t y   g o o d   s i z e   c h u r c h .
#     Ground Truth : It's a pretty good size church.
# ------------------------------------------------------------
# [854] Prediction   : c a m p i n g   f o r   y o u   i n   a   m o t o r   h o m e .
#     Ground Truth : Camping for you in a motor home.
# ------------------------------------------------------------
# [855] Prediction   : i f   y o u ' v e   o n l y   g o t   a   t o k e n   f o r c e   t h e r e .
#     Ground Truth : If you've only got a token force there.
# ------------------------------------------------------------
# [856] Prediction   : t h i s   t i m e   o f   t h e   y e a r .
#     Ground Truth : This time of the year.
# ------------------------------------------------------------
# [857] Prediction   : i ' d   j u s t   a s   s o o n   a   l o t   f e w e r   p e o p l e   d i d .
#     Ground Truth : I'd just as soon a lot fewer people did.
# ------------------------------------------------------------
# [858] Prediction   : t h e y   t h i n k   i t ' s   k i n d   o f   c o o l .
#     Ground Truth : They think it's kind of cool.
# ------------------------------------------------------------
# [859] Prediction   : c r i m e   i s   t o o   m u c h .
#     Ground Truth : Crime is too much.
# ------------------------------------------------------------
# [860] Prediction   : i   d o n ' t   k n o w   h o w   m y   f a t h e r   d i d   i t .
#     Ground Truth : I don't know how my father did it.
# ------------------------------------------------------------
# [861] Prediction   : l i v e d   o n   a   f a r m   f o r   s i x t y   y e a r s .
#     Ground Truth : Lived on a farm for sixty years.
# ------------------------------------------------------------
# [862] Prediction   : i   l o o k   a t   h o m e m a k i n g   a s   a   j o b   a l s o .
#     Ground Truth : I look at homemaking as a job also.
# ------------------------------------------------------------
# [863] Prediction   : r e a l l y   k i n d   o f   g o n e   t h e   r o u n d s .
#     Ground Truth : Really kind of gone the rounds.
# ------------------------------------------------------------
# [864] Prediction   : i   n e v e r   e v e n   k n e w   t h a t .
#     Ground Truth : I never even knew that.
# ------------------------------------------------------------
# [865] Prediction   : c l o t h i n g   a n d   g a s .
#     Ground Truth : Clothing and gas.
# ------------------------------------------------------------
# [866] Prediction   : t h e   c o m m e r c i a l   d i s t r i c t s .
#     Ground Truth : The commercial districts.
# ------------------------------------------------------------
# [867] Prediction   : w h a t ' s   t h e   d i f f e r e n c e   t h e r e ?
#     Ground Truth : What's the difference there?
# ------------------------------------------------------------
# [868] Prediction   : i   l i k e   t h a t   k i n d   o f   s t u f f .
#     Ground Truth : I like that kind of stuff.
# ------------------------------------------------------------
# [869] Prediction   : w e   m i g h t   a s   w e l l .
#     Ground Truth : We might as well.
# ------------------------------------------------------------
# [870] Prediction   : s a v i n g s   a n d   l o a n s .
#     Ground Truth : Savings and loans.
# ------------------------------------------------------------
# [871] Prediction   : t h e y   p l a s t e r e d   o v e r   d r y w a l l .
#     Ground Truth : They plastered over drywall.
# ------------------------------------------------------------
# [872] Prediction   : i ' l l   s l i c e   w h i t e   g r a p e .
#     Ground Truth : I'll slice white grape.
# ------------------------------------------------------------
# [873] Prediction   : t h e   b o m b   d e v e l o p m e n t .
#     Ground Truth : The bomb development.
# ------------------------------------------------------------
# [874] Prediction   : o n   t h e   o u t s k i r t s   o f   h o u s t o n .
#     Ground Truth : On the outskirts of Houston.
# ------------------------------------------------------------
# [875] Prediction   : i   f o r g e t   h o w   s h e   g o t   i t .
#     Ground Truth : I forget how she got it.
# ------------------------------------------------------------
# [876] Prediction   : y o u r   t u i t i o n   r e i m b u r s e m e n t .
#     Ground Truth : Your tuition reimbursement.
# ------------------------------------------------------------
# [877] Prediction   : g e t t i n g   p l e d g e   s h e e t s   f o r   t h e   b o y   s c o u t s .
#     Ground Truth : Getting pledge sheets for the Boy Scouts.
# ------------------------------------------------------------
# [878] Prediction   : i f   y o u   h a v e   a n y   d o u b t s   w h a t s o e v e r .
#     Ground Truth : If you have any doubts whatsoever.
# ------------------------------------------------------------
# [879] Prediction   : m y s t e r y   m o v i e s .
#     Ground Truth : Mystery movies.
# ------------------------------------------------------------
# [880] Prediction   : i   c a n ' t   r e m e m b e r   w h e r e .
#     Ground Truth : I can't remember where.
# ------------------------------------------------------------
#
# 🎯 Final Corpus BLEU Score: 0.0000
# d:\NeuroAi\myenv_tf\lib\site-packages\nltk\translate\bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# d:\NeuroAi\myenv_tf\lib\site-packages\nltk\translate\bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# d:\NeuroAi\myenv_tf\lib\site-packages\nltk\translate\bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
